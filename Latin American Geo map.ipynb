# %% [markdown]
# <a href="https://colab.research.google.com/github/jgkorman/Python-Projects/blob/main/Latin%20American%20Geo%20map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Problem Statement**

# %% [markdown]
# Democracy, is a contested word that has no true definition that can serve as a [panacea](https://books.google.com/books?hl=en&lr=&id=uiFH5dh12p0C&oi=fnd&pg=PR11&dq=democracy+and+development+adam+przeworski&ots=xmja4TCxkx&sig=TJb92nki_wdZfoHMsesvRPGJxjg#v=onepage&q=democracy%20and%20development%20adam%20przeworski&f=false). However, one generally accepted definition is that democracy protects the rights of minorities and institutionalizes [uncertainty](https://books.google.com/books?hl=en&lr=&id=6wJvFVyhKJwC&oi=fnd&pg=PP1&dq=juan+linz+and+schmitter+transitions+from+authoritarianism&ots=2xIU-WQ0Pm&sig=tycVeJPCIecSWW2KuRgWfXT0FMQ#v=onepage&q=juan%20linz%20and%20schmitter%20transitions%20from%20authoritarianism&f=false). It does so in the following way: although the majority may be in power today, through free and fair elections, there is always the chance that the minority could come back to take power. This is what we mean by protecting the rights of minorities -- the majority is not able to stack the deck in their hands to ensure that the minority has no chance at winning or getting their policies passed through. This form of democracy, what we call liberal democracy, is under threat from authoritarianism and democratic backsliding like never before. Even the United States – the world's longest standing democracy -- is now categorized as a [democracy in decline.](https://www.idea.int/blog/democratic-backsliding-different-causes-divergent-trajectories)
#
#
# This democratic backsliding is having grave implications for world freedom and prosperity as free and fair elections – a pivotal component of democracy – [are being undermined](https://scholar.harvard.edu/levitsky/files/SL_elections.pdf). This is causing less and less people to ultimately have a voice and or say in matters that impact them and their daily lives.
#
# This democratic backsliding and shift towards authoritarianism is caused by multiple mechanisms. For one, backsliding occurs on behalf of state actors that [deliberately undermine](https://www.idea.int/blog/democratic-backsliding-different-causes-divergent-trajectories) democratic political institutions in a given country. Actions that damage horizontal constraints in a given country are also a causal mechanism for the decline in democracy such as attacks on the legislature and the courts along with proposed laws and measures that challenge election and media integrity – along with the degradation of civil liberties. Another huge cause of backsliding is the concept of [‘majoritarianism’](https://igcc.ucsd.edu/news-events/news/why-is-democratic-backsliding-on-the-rise.html) whereby the majority who win in an election think they have an extreme mandate to rule without cause for concern for the losers in an election. Polarization between citizens only [exacerbates](https://igcc.ucsd.edu/news-events/news/why-is-democratic-backsliding-on-the-rise.html) the backsliding trend.
#
#
# As a current example of the dangers of democracy in decline - and if we need any more look that democracy is [under attack and in decline](https://freedomhouse.org/country/venezuela/freedom-world/2021), simply look at the case of Venezuela (a country pertinent to our analyses) over the years. Venezuela was once a model democracy but has since experienced a deep democratic decline to the point where the country is now a full blown authoritarian state. This has implications not only for the country's institutions such as its court system and integrity of the rule of law, but also weakens civil society and arguably makes the population worse off.
#
# However, this trend in democratic backsliding may not be the same in all places world wide. Perhaps some regions of the world are sliding into democratic regress whereas others may be strengthening their democratic foundations. In order to analyze this, we pull from the [Varieties of Democracy index](http://v-dem.net/vdemds.html) using the liberal democracy indicator that measures the extent of liberal democracy of a given country on a normalized scale ranging from 0-1. By liberal democracy – the measure refers to the extent surrounding the importance of protecting minority rights against tyranny of the majority. In liberal democracies, this is achieved via constitutional means that protect civil liberties, the rule of law including a strong and independent judiciary, and effective checks and balances that limit the exercise of executive power.
#
# Overall, this trend worldwide is concerning because we also know that people are generally [more satisfied and happy](https://sites.psu.edu/tetirclblog/2015/10/12/the-correlation-between-democracy-and-happiness/) living in democracies. Thus, the policy implications of democratic rule cannot be discounted as people’s general well-being is much more robust under democratic rule relative to authoritarian rule.
#
#
#
# ---
#
#
#
# Together with the changes in democracy, the other indicator will be changes in level of happiness. Since 2012, Sustainable Development Solutions Network has released the yearly [World Happiness Report](https://worldhappiness.report/archive/). This report uses the [Gallup World Poll (GWP)](https://www.gallup.com/178667/gallup-world-poll-work.aspx). This poll asks respondents, from nationally representative samples, to think of a ladder (Cantril ladder technique) with the best possible life for them being a ten and the worst life being a 0, and they are asked to rate their own life based on that scale. Each country's final rank is based entirely on the Gallup weights' survey scores to make the estimates representative. Even though the ladder score (mean of all rankings per country) is the primary indicator of happiness, the report also includes other descriptive statistics of that indicator, such as standard error of ladder score, upper whisker, and lower whisker. In addition to the ladder score, there are six factors (GDP per capita, life expectancy, generosity, social support, freedom, and corruption) used to estimate to what extent each contributes to making happiness evaluations in each country higher than in Dystopia. Dystopia is the hypothetical country with the lowest scores observed for each of the six factors. This imaginary country would have the world's least-happy people; therefore, no country can perform worse than Dystopia, establishing a benchmark against which all countries can be compared.
#
# In all, it is compelling to the democratic community to understand the current trends in democratic norms and civil liberties to act proactively in preventing the kinds of authoritarianism that threatens to destabilize the current world order and upend the global economic system. Analyzing trends over time may allow researchers to identify the signs and markers of democratic backslide at their nascent stages and recommend policy action to reverse the trend. History is often said to repeat itself, and understanding the causes of past events is crucial in understanding how future events may play out.
#
# Based upon the Global Happiness Report, we believe that the report index may be a useful indicator of periods of change in a country. We believe that it is plausible that the happier folks in a country are, the more likely they are to support the status quo, and the less likely it is to see a backsliding or improving democracy. Likewise, if the people of a nation are unhappy, it would be plausible to see evidence of changing democratic norms as unhappy people demand change. If this association is correct, then it may inform policy decisions to maximize the happiness of people (and improve the factors that contribute to the happiness score) in order to maintain stability in a country and around the world.
#
#
#
# ---
#
#
#
# **For this study, we pose the following questions:**
#
# * For the Latin American region: our main research questions are the following:
#
# 1. How do our main features vary and can we identify any clustering of Latin American countries based upon our main features (rule of law, liberal democracy & civil society strength for the time period 1960-2021?).
#
# 2. What are the most important features for predicting and enhancing levels of liberal democracy w/ data from 1960-2021?
#
# > Two Analyses will be used to answer this second question: logistic     regression & decision tree regression to analyze this question in both probabilistic terms individually for each feature predicting our target (liberal democracy) for logistic regression; and collectively in one combined model with all of our features in the decision tree regression context.

# %% [markdown]
# # **2. Setting up our coding environment and installing necessary libraries**

# %% [markdown]
# 1.   Happiness Data for years 2015-2019 comes from: https://www.kaggle.com/unsdsn/world-happiness?select=2019.csv
# 2.   Geoshape files for Latin AMerican countries come from: https://www.diva-gis.org/gdata
# 3. Varieties of Democracy Data come from: https://www.v-dem.net/vdemds.html to obtain our democracy DV -- rule of law IV -- and civil society participation IV

# %%
# !pip install geopandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('bmh')
import numpy as np
import plotly.express as px
import geopandas as gp
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/V-Dem-CY-Core-v12.csv"
democracy = pd.read_csv(fname)

# %% [markdown]
# # **3. Creating our main democracy dataframe for the Latin American region**

# %%
cols = ['country_name', 'year', 'v2x_libdem', 'v2x_cspart', 'v2x_rule']
democracy = democracy[cols]
democracy
# Out:
#             country_name  year  v2x_libdem  v2x_cspart  v2x_rule
# 0                 Mexico  1789       0.040       0.037     0.249
# 1                 Mexico  1790       0.040       0.037     0.249
# 2                 Mexico  1791       0.040       0.037     0.249
# 3                 Mexico  1792       0.040       0.037     0.249
# 4                 Mexico  1793       0.040       0.037     0.249
# ...                  ...   ...         ...         ...       ...
# 27375  Piedmont-Sardinia  1857       0.138       0.197     0.533
# 27376  Piedmont-Sardinia  1858       0.138       0.197     0.533
# 27377  Piedmont-Sardinia  1859       0.138       0.197     0.533
# 27378  Piedmont-Sardinia  1860       0.139       0.197     0.533
# 27379  Piedmont-Sardinia  1861       0.140       0.333     0.533
#
# [27380 rows x 5 columns]

# %% [markdown]
# Cleaning the original dataset -- getting only the variables that we need (only viable countries)

# %%
# Make countries the index to filter them with ease
democracy = democracy.set_index('country_name')

# Get A List of Counrties we want to remove
countries = ['Palestine/British Mandate', 'Baden', 'Bavaria', 'Modena', 'Parma', 'Saxony', 'Tuscany', 'Würtemberg', 'Two Sicilies', 'Hanover', 'Hesse-Kassel', 'Hesse-Darmstadt', 'Mecklenburg Schwerin', 'Papal States', 'Hamburg', 'Brunswick','Oldenburg', 'Saxe-Weimar-Eisenach', 'Nassau', 'Piedmont-Sardinia', 'Vanuatu', 'Seychelles', 'Sao Tome and Principe', 'Solomon Islands', 'Republic of Vietnam', 'Maldives', 'Palestine/West Bank', 'Eswatini', 'Palestine/Gaza', 'Somaliland', 'Zanzibar']
# dropping the counteis list we don't need
democracy = democracy.drop(countries)
# Creating a DF for only Latin American Countries
# Creating a list of Latin American countries to create the Latin AMerican Dataframe
DemocracyLatinAmerica = ['Mexico', 'Colombia', 'Brazil', 'El Salvador', 'Bolivia', 'Honduras', 'Peru', 'Argentina', 'Venezuela', 'Nicaragua', 'Chile', 'Costa Rica', 'Ecuador', 'Guatemala', 'Panama', 'Uruguay', 'Dominican Republic', 'Cuba', 'Guyana', 'Paraguay']
#The Latin Americna dataframe filtered w/ only Latin American countries
DemocracyLatinAmerica = democracy.loc[DemocracyLatinAmerica]
# resetting the index
DemocracyLatinAmerica = DemocracyLatinAmerica.reset_index()
# Creating the dataframe so that we are only dealing with values from year 1960 onwards
LATAMafter1900 = DemocracyLatinAmerica['year'] >= 1960
DemocracyLatinAmerica = DemocracyLatinAmerica[LATAMafter1900]
DemocracyLatinAmerica
# Out:
#      country_name  year  v2x_libdem  v2x_cspart  v2x_rule
# 171        Mexico  1960       0.106       0.139     0.241
# 172        Mexico  1961       0.106       0.139     0.241
# 173        Mexico  1962       0.107       0.139     0.241
# 174        Mexico  1963       0.107       0.139     0.241
# 175        Mexico  1964       0.106       0.139     0.241
# ...           ...   ...         ...         ...       ...
# 4068     Paraguay  2017       0.418       0.592     0.369
# 4069     Paraguay  2018       0.417       0.585     0.418
# 4070     Paraguay  2019       0.419       0.596     0.431
# 4071     Paraguay  2020       0.421       0.561     0.434
# 4072     Paraguay  2021       0.426       0.561     0.471
#
# [1240 rows x 5 columns]

# %% [markdown]
# How many unique countries in the Laitn American Dataset

# %%
len(DemocracyLatinAmerica['country_name'].unique())
# Out:
# 20

# %% [markdown]
# # **4. Creating the Geodataframe for the Latin American region**

# %% [markdown]
# **Getting the individual geos for each of our 20 latam countries to create a geodataframe**

# %%
# Mexico
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Mexico/MEX_adm0.shp"
Mexico = gp.read_file(fname)
Mexicogeo = Mexico['geometry']

# Paraguay
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Paraguay/Paraguay/PRY_adm0.shp"
Paraguay = gp.read_file(fname)
Paraguaygeo = Paraguay['geometry']

# Colombia
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Colombia/Colombia/COL_adm0.shp"
Colombia = gp.read_file(fname)
Colombiageo = Colombia['geometry']

# Brazil
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Brazil/Brazil/BRA_adm0.shp"
Brazil = gp.read_file(fname)
Brazilgeo = Brazil['geometry']
# El Salvador
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/El Salvador/El Salvador/SLV_adm0.shp"
El_Salvador = gp.read_file(fname)
El_Salvadorgeo = El_Salvador['geometry']
# bolivia
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Bolivia/Bolivia/BOL_adm0.shp"
Bolivia = gp.read_file(fname)
Boliviageo = Bolivia['geometry']
# Honduras
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Honduras/Honduras/HND_adm0.shp"
Honduras = gp.read_file(fname)
Hondurasgeo = Honduras['geometry']
# Peru
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Peru/Peru/PER_adm0.shp"
Peru = gp.read_file(fname)
Perugeo = Peru['geometry']
# Argentina
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Argentina/Argentina/ARG_adm0.shp"
Argentina = gp.read_file(fname)
Argentinageo = Argentina['geometry']
# Venezuela
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Venezuela/Venezuela/VEN_adm0.shp"
Venezuela = gp.read_file(fname)
Venezuelageo = Venezuela['geometry']
# Nicragua
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Nicaragua/Nicaragua/NIC_adm0.shp"
Nicaragua = gp.read_file(fname)
Nicaraguageo = Nicaragua['geometry']
# Chile
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Chile/Chile/CHL_adm0.shp"
Chile = gp.read_file(fname)
Chilegeo = Chile['geometry']
# Costa Rica
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Costa Rica/Costa Rica/CRI_adm0.shp"
CostaRica = gp.read_file(fname)
CostaRicageo = CostaRica['geometry']
# Ecuador
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Ecuador/Ecuador/ECU_adm0.shp"
Ecuador = gp.read_file(fname)
Ecuadorgeo = Ecuador['geometry']
# Guatemala
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Guatemala/Guatemala/GTM_adm0.shp"
Guatemala = gp.read_file(fname)
Guatemalageo = Guatemala['geometry']
# Panama
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Panama/Panama/PAN_adm0.shp"
Panama = gp.read_file(fname)
Panamageo = Panama['geometry']
# Uruguay
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Uruguay/Uruguay/URY_adm0.shp"
Uruguay = gp.read_file(fname)
Uruguaygeo = Uruguay['geometry']
# Dominican Republic
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Dominican Republic/Dominican Republic/DOM_adm0.shp"
DominicanRepublic = gp.read_file(fname)
DominicanRepublicgeo = DominicanRepublic['geometry']
# Cuba
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Cuba/Cuba/CUB_adm0.shp"
Cuba = gp.read_file(fname)
Cubageo = Cuba['geometry']
# Guyana
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/Latin America Shape Files/Guyana/Guyana/GUY_adm0.shp"
Guyana = gp.read_file(fname)
Guyanageo = Guyana['geometry']

# Creating the GeoDATAFRAME
# Extracting out the country names from Latin American democracy dataframe to add into the geodataframe as a column
countries = DemocracyLatinAmerica['country_name']

for ii in countries:
  ii = countries.unique()

country = pd.Series(ii)

# appending all of our individual country geos to create the Latin American geodataframe
latamgeos = Mexicogeo.append(Colombiageo).append(Brazilgeo).append(El_Salvadorgeo).append(Boliviageo).append(Hondurasgeo).append(Perugeo).append(Argentinageo).append(Venezuelageo).append(Nicaraguageo).append(Chilegeo).append(CostaRicageo).append(Ecuadorgeo).append(Guatemalageo).append(Panamageo).append(Uruguaygeo).append(DominicanRepublicgeo).append(Cubageo).append(Guyanageo).append(Paraguaygeo).reset_index()
# adding the 'country' series back into the dataframe
latamgeos['country'] = country
# dropping the index that we don't need
latamgeos = latamgeos.drop(columns='index')
# renaming the columns
latamgeos.columns = ['geometry', 'country']
# the Latin AMerican geodataframe
latamgeos
# Out:
# /usr/local/lib/python3.10/dist-packages/geopandas/geoseries.py:622: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val = getattr(super(), mtd)(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/geopandas/geoseries.py:622: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val = getattr(super(), mtd)(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/geopandas/geoseries.py:622: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val = getattr(super(), mtd)(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/geopandas/geoseries.py:622: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
import matplotlib.pyplot as plt

# Load your dataframe with geometries
# Assuming your dataframe is named 'gdf'
# Load it with gdf = gpd.GeoDataFrame(dataframe_name)

# Set up a base plot
fig, ax = plt.subplots(figsize=(10, 10))
latamgeos.plot(ax=ax, color='blue')  # Plot all geometries in blue

# Select the geometry at index 18 and color it in red
latamgeos.iloc[18:19].plot(ax=ax, color='red')  # Plot only the geometry at index 18 in red

# Show the plot
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Assuming 'latamgeos' is your GeoDataFrame

# Set up the base plot
fig, ax = plt.subplots(figsize=(8, 8))
latamgeos.boundary.plot(ax=ax, linewidth=0.8, color='black')  # Plot country boundaries in black
latamgeos.plot(ax=ax, color='lightgray')  # Plot all geometries with a light gray fill

# Select the geometry at index 18 and color it in red
latamgeos.iloc[18:19].plot(ax=ax, color='red', alpha=0.5)  # Plot only the geometry at index 18 in red with some transparency

# Add country names as labels
for idx, row in latamgeos.iterrows():
    ax.annotate(text=row['country'], xy=row['geometry'].centroid.coords[0], ha='center', fontsize=8)

ax.set_title('Latin American Countries')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'latamgeos' is your GeoDataFrame

# Set up the base plot
fig, ax = plt.subplots(figsize=(10, 10))
latamgeos.boundary.plot(ax=ax, linewidth=0.8, color='black')  # Plot country boundaries in black
latamgeos.plot(ax=ax, color='lightgray')  # Plot all geometries with a light gray fill

# Select the geometry at index 18 and color it in red
latamgeos.iloc[18:19].plot(ax=ax, color='red', alpha=0.5)  # Plot only the geometry at index 18 in red with some transparency

# Add country names as labels
for idx, row in latamgeos.iterrows():
    ax.annotate(text=row['country'], xy=row['geometry'].centroid.coords[0], ha='center', fontsize=10)

# Get rid of axis lines and ticks and tick labels
ax.set_axis_off()

ax.set_title('Latin American Countries', fontsize = 20)

# Show the plot
plt.show()

# %%
latamgeos.plot()
# Out:
# <Axes: >

# %% [markdown]
# # **5. Creating the happiness dataframe for Latin American countries 2015-2019**

# %%
# 2015 Happiness Data
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/HappinessData2015-2019/2015Happy.csv"
Happy2015 = pd.read_csv(fname)
cols = ['Country', 'Happiness Score']
Happy2015 = Happy2015[cols]

# 2016 Happiness Data
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/HappinessData2015-2019/2016Happy.csv"
Happy2016 = pd.read_csv(fname)
cols = ['Country or region', 'Score']
Happy2016 = Happy2016[cols]

# 2017 Happiness Data
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/HappinessData2015-2019/2017Happy.csv"
Happy2017 = pd.read_csv(fname)
Happy2017.head(2)
cols = ['Country', 'Happiness.Score']
Happy2017 = Happy2017[cols]

# 2018 Happiness Data
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/HappinessData2015-2019/2018Happy.csv"
Happy2018 = pd.read_csv(fname)
Happy2018.head(2)
cols = ['Country or region', 'Score']
Happy2018 = Happy2018[cols]

# 2019 Happiness Data
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/HappinessData2015-2019/2019Happy.csv"
Happy2019 = pd.read_csv(fname)
Happy2019.head(2)
cols = ['Country or region', 'Score']
Happy2019 = Happy2019[cols]

# Dropping Cuba & Guyana From the "country" Pandas Series created earlier given they don't have any data in the Happiness data to merge together
country = country.drop(labels=[17, 18], axis=0)

# Merging the Happiness DataFrames together for ata 2015 to 2019
Happy = Happy2015.merge(Happy2016, left_on='Country', right_on='Country or region')
Happy = Happy.drop(columns='Country or region')
Happy = Happy.merge(Happy2017, left_on='Country', right_on='Country')
Happy = Happy.merge(Happy2018, left_on='Country', right_on='Country or region')
Happy = Happy.drop(columns='Country or region')
Happy = Happy.merge(Happy2019, left_on='Country', right_on='Country or region')
Happy = Happy.drop(columns='Country or region')
cols = ['Country', 'Happy2015', 'Happy2016', 'Happy2017', 'Happy2018', 'Happy2019']
Happy.columns = cols
Happy = Happy.set_index('Country')
Happy = Happy.loc[country].reset_index()
Happy
# Out:
#                Country  Happy2015  Happy2016  Happy2017  Happy2018  Happy2019
# 0               Mexico      7.187      6.595      6.578      6.488      6.595
# 1             Colombia      6.477      6.125      6.357      6.260      6.125
# 2               Brazil      6.983      6.300      6.635      6.419      6.300
# 3          El Salvador      6.130      6.253      6.003      6.167      6.253
# 4              Bolivia      5.890      5.779      5.823      5.752      5.779
# 5             Honduras      4.788      5.860      5.181      5.504      5.860
# 6                 Peru      5.824      5.697      5.715      5.663      5.697
# 7            Argentina      6.574      6.086      6.599      6.388      6.086
# 8            Venezuela      6.810      4.707      5.250      4.806      4.707
# 9            Nicaragua      5.828      6.105      6.071      6.141      6.105
# 10               Chile      6.670      6.444      6.652      6.476      6.444
# ...

# %% [markdown]
# # **6. Summary Plots of our main Latin American democracy dataset**

# %%
DemocracyLatinAmerica.describe()[['v2x_libdem',	'v2x_cspart',	'v2x_rule']]
# Out:
#         v2x_libdem   v2x_cspart     v2x_rule
# count  1240.000000  1240.000000  1240.000000
# mean      0.341906     0.579135     0.439940
# std       0.251624     0.259788     0.269643
# min       0.017000     0.046000     0.009000
# 25%       0.085000     0.366500     0.246000
# 50%       0.313500     0.661000     0.401500
# 75%       0.523500     0.793000     0.618750
# max       0.865000     0.972000     0.965000

# %% [markdown]
# The Table above shows the descriptive statistics for liberal democracy, civil soceity strength, and the rule of law strength respectively for Latin American countries from 1960-2020. Overall, as shown via the mean and median, Latin America is a region with relatively weak levels of democracy, middle levels of civil society strength, and a weak-to-middle level of the strength of the rule of law

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
DemocracyLatinAmerica.hist('v2x_libdem', ax=ax[0])
DemocracyLatinAmerica['v2x_libdem'].plot(kind='density', ax=ax[1])

ax[0].set_title('Liberal Democracy Histogram')
ax[1].set_title('Density plot Liberal Democracy')
# Out:
# Text(0.5, 1.0, 'Density plot Liberal Democracy')

# %% [markdown]
# **Figure 1** plots a histogram on the left panel and a density plot on the right panel of our main dependent variable "democracy". Overall, for ocuntries in the Latin American region -- we have a semi normal distribution -- however, there appears to be a cluster of values in the lower range of variable that appear to be contributing to a right skweness.

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,5))
DemocracyLatinAmerica.hist('v2x_cspart', ax=ax[0])
DemocracyLatinAmerica.hist('v2x_rule', ax=ax[1])

ax[0].set_title('Civil Society Participation')
ax[1].set_title('Strenght of Rule of Law')
# Out:
# Text(0.5, 1.0, 'Strenght of Rule of Law')

# %% [markdown]
# **Figure 2** Plots a histogram of 2 our key independent variables for Latin American region -- civil society participation in the left panel and the strength of rule of law in the right panel. Overall, Latin American countires appear to have pretty strong levels of civil society participation over the years 1960-2020 while during the same years -- Latin American countries also appear to have a relatively weak rule of law.

# %%
# Resetting the Index

DemocracyLatinAmerica = DemocracyLatinAmerica.reset_index()
DemocracyLatinAmerica = DemocracyLatinAmerica.drop(columns='index')

# Grouping our data by the Year & Average for our Latin AMerican countries for summary plots
LATAMgroupby = DemocracyLatinAmerica.groupby(['year']).mean().reset_index()
LATAMgroupby
# Out:
# <ipython-input-14-2c0ebf54cfad>:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   LATAMgroupby = DemocracyLatinAmerica.groupby(['year']).mean().reset_index()
#     year  v2x_libdem  v2x_cspart  v2x_rule
# 0   1960     0.22940     0.40920   0.41265
# 1   1961     0.23115     0.41160   0.41035
# 2   1962     0.21930     0.42115   0.41350
# 3   1963     0.22165     0.43575   0.42630
# 4   1964     0.22105     0.41350   0.40895
# ..   ...         ...         ...       ...
# 57  2017     0.46740     0.70500   0.52355
# 58  2018     0.46485     0.70120   0.51540
# 59  2019     0.45000     0.68425   0.51670
# 60  2020     0.44150     0.67365   0.52510
# 61  2021     0.43525     0.66055   0.52870
#
# [62 rows x 4 columns]

# %%
fig, ax = plt.subplots(1, 3, figsize=(14, 7))
LATAMgroupby.plot('year', 'v2x_libdem', ax=ax[0], kind='line', label='Liberal Democracy', color='red')
LATAMgroupby.plot('year', 'v2x_cspart', ax=ax[1], kind='line', label='Civil Society Participation', color='blue')
LATAMgroupby.plot('year', 'v2x_rule', ax=ax[2], kind='line', label='Rule of Law', color='black')
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# **Figure 3** plots line plots of averages over time 1960-2020 our three variables (the DV liberal democracy on the left panel -- the IV civil society participaiton on the middle panel, and the other main IV rule of law on the right panel. Overall, with all three measures show a drop from the 1960s until the 1980s -- with an uptick in all 3 measures that sustains itself beginning right around the 1980s -- coinciding with democratizaiton in the region.

# %%
LATAMgroupby2 = DemocracyLatinAmerica.groupby(['year', 'country_name']).mean().unstack('country_name')
#save for later anlaysis

# grouping by country in order to plot country level means
meanplots = DemocracyLatinAmerica.groupby('country_name').mean().reset_index()
meanplots = meanplots.drop(columns='year')

# %% [markdown]
# **Merge the geodataframe and the groupby dataframe of the averages of our variables over time 1960-2021**

# %%
geomeanLATAMdf = latamgeos.merge(meanplots, left_on='country', right_on='country_name')
geomeanLATAMdf
# Out:
#                                              geometry             country  \
# 0   MULTIPOLYGON (((-92.86236 15.16819, -92.86236 ...              Mexico
# 1   MULTIPOLYGON (((-78.95875 1.60097, -78.95875 1...            Colombia
# 2   MULTIPOLYGON (((-52.07069 -32.02847, -52.07069...              Brazil
# 3   MULTIPOLYGON (((-87.68570 13.17592, -87.68569 ...         El Salvador
# 4   POLYGON ((-65.32160 -9.80977, -65.32056 -9.814...             Bolivia
# 5   MULTIPOLYGON (((-87.42931 13.10403, -87.42931 ...            Honduras
# 6   MULTIPOLYGON (((-71.38486 -17.70930, -71.38486...                Peru
# 7   MULTIPOLYGON (((-66.54916 -55.05958, -66.54916...           Argentina
# 8   MULTIPOLYGON (((-60.64264 8.68403, -60.64264 8...           Venezuela
# 9   MULTIPOLYGON (((-86.00291 11.35292, -86.00291 ...           Nicaragua
# 10  MULTIPOLYGON (((-67.31805 -55.96819, -67.31805...               Chile
# 11  MULTIPOLYGON (((-87.04792 5.55681, -87.04792 5...          Costa Rica
# ...

# %%
# Getting the centroids for our analysis

chilecenter = geomeanLATAMdf[geomeanLATAMdf['country_name'] == 'Chile']
chilecenter = chilecenter.centroid

uruguaycenter = geomeanLATAMdf[geomeanLATAMdf['country_name'] == 'Uruguay']
uruguaycenter = uruguaycenter.centroid

costaricacenter = geomeanLATAMdf[geomeanLATAMdf['country_name'] == 'Costa Rica']
costaricacenter = costaricacenter.centroid
# Out:
# <ipython-input-18-a89c9e82ae1e>:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   chilecenter = chilecenter.centroid
# <ipython-input-18-a89c9e82ae1e>:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   uruguaycenter = uruguaycenter.centroid
# <ipython-input-18-a89c9e82ae1e>:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   costaricacenter = costaricacenter.centroid

# %%
fig, ax = plt.subplots(figsize=(15,8))
geomeanLATAMdf.plot('v2x_libdem', ax=ax, cmap='plasma', legend=True)
chilecenter.plot(ax=ax)
fig.text(.83, .2, "Latin American Liberal Democracy 1960-2021", rotation=270, weight='bold', fontsize=14)
fig.text(.47, .66, 'Costa Rica')
fig.text(.53, .33, 'Chile')
fig.text(.60, .33, 'Uruguay')
ax.set_title('Average Liberal Democracy Score 1960-2021 across Latin American countries', weight='bold')
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %% [markdown]
# **Figure 4** plots a choropleth of the average Liberal democracy score for all Latin American countries 1960-2021. Overall, we see a wide variaiton in the strengh of liberal democracy with 3 countries in particular standing out: Chile, Uruguay, and Costa Rica for their high levels of democracy.

# %%
fig, ax = plt.subplots(figsize=(15,8))
geomeanLATAMdf.plot('v2x_cspart', ax=ax, cmap='plasma', legend=True)
fig.text(.83, .2, "Latin American Civil Society Strength 1960-2021", rotation=270, weight='bold', fontsize=14)
fig.text(.47, .66, 'Costa Rica')
fig.text(.53, .33, 'Chile')
fig.text(.60, .33, 'Uruguay')
ax.set_title('Average Civil Society Strength Score 1960-2021 across Latin American countries', weight='bold')
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %% [markdown]
# **Figure 5** plots the average civil soceity strength for Latin American countries acrossthe years 1960-2021. Overall, there is a alot of variation in the region but once more I'd like to highlight the same three countries here in this plot.

# %%
fig, ax = plt.subplots(figsize=(15,8))
geomeanLATAMdf.plot('v2x_rule', ax=ax, cmap='plasma', legend=True)
fig.text(.83, .2, "Latin American Rule of Law Strength 1960-2021", rotation=270, weight='bold', fontsize=14)
fig.text(.47, .66, 'Costa Rica')
fig.text(.53, .33, 'Chile')
fig.text(.60, .33, 'Uruguay')
ax.set_title('Average Rule of Law Strength Score 1960-2021 across Latin American countries', weight='bold')
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %% [markdown]
# **Figure 6** plots the average rule of law strength across Latin American countries for the years 1960 through 2021. Once more -- Chile, Costa Rica, and Uruguay, all highlighted in this map annotated -- have scored above the rest on this measure as well.

# %% [markdown]
# **Plotting the Happiness Data basic descriptive stats**

# %%
Happy.describe()
# Out:
#        Happy2015  Happy2016  Happy2017  Happy2018  Happy2019
# count  18.000000  18.000000  18.000000  18.000000  18.000000
# mean    6.251056   6.075778   6.113000   6.071278   6.075778
# std     0.689894   0.520536   0.563627   0.535494   0.520536
# min     4.788000   4.707000   5.181000   4.806000   4.707000
# 25%     5.881000   5.799250   5.742000   5.698750   5.799250
# 50%     6.303500   6.115000   6.214000   6.213500   6.115000
# 75%     6.757000   6.315750   6.547000   6.411250   6.315750
# max     7.226000   7.167000   7.079000   7.072000   7.167000

# %% [markdown]
# The table above shows the descriptive statistics for our happiness dataset for our Latin American countries. Overall, looking at the mean and median scores, Latin America across the board is relatively happy although it does appear to have a decrease in average happiness as the years go by. The range in happiness scores for the years is also quite substantial as well.

# %%
fig, ax = plt.subplots(2, 2, figsize=(10,5))
Happy.hist('Happy2015', ax=ax[0, 0])
ax[0, 0].axvline([Happy['Happy2015'].mean()], color='red')

Happy.hist('Happy2016', ax=ax[0, 1])
ax[0, 1].axvline([Happy['Happy2016'].mean()], color='red')

Happy.hist('Happy2017', ax=ax[1, 0])
ax[1, 0].axvline([Happy['Happy2017'].mean()], color='red')

Happy.hist('Happy2018', ax=ax[1, 1])
ax[1, 1].axvline([Happy['Happy2018'].mean()], color='red')

fig, ax = plt.subplots(figsize=(5,3))
Happy.hist('Happy2019', ax=ax)
ax.axvline([Happy['Happy2019'].mean()], color='red')

# %% [markdown]
# **Figure 7** plots histograms for each of our 5 years of happiness data for 17 Latin American countries (Cuba and Guyana dropped due to lack of data). Overall, happiness appears to be relatively steady for the time period 2015-2019. The mean happiness across all Latin American countries is shown in the red line in each panel plot. The data however, do not appear normally distributed as is characteristic by a nice round looking bell-curve. With that said, given we have an n of 17, we can't truly make any meaningful conclusions about the shape of the distribution -- especially given the low n.

# %%
# Transposing the Happy dataframe to plot happiness scores across years 2015 to 2019 for all Latin AMerican countries
HappyT=Happy.set_index('Country').T
HappyTnp = HappyT.values


fig, ax = plt.subplots(figsize=(10,5))
ax.plot(HappyTnp[0].T, label='2015 Happiness Scores')
ax.plot(HappyTnp[1].T, label='2016 Happiness Scores')
ax.plot(HappyTnp[2].T, label='2017 Happiness Scores')
ax.plot(HappyTnp[3].T, label='2018 Happiness Scores')
ax.plot(HappyTnp[4].T, label='2019 Happiness Scores')

ax.set_xticks([])
ax.set_ylabel("Happiness Scores", fontsize=14, weight='bold')
ax.set_title('Happiness Scores over time 2015-2019 Latin America', weight='bold')


ax.legend()

# %% [markdown]
# **Figure 9** plots the time series for our happiness data for 2015 to 2019 showing the variation in happiness scores for our given Latin American countries for the respective year. Overall, there is markedly little variation between happiness scores from one year to the next.

# %%
# Below I'm merging our 1960-2021 groupby Latin American average dataframe that was merged with the Latin American geos with the Happiness dataset so all 3 datasets are merged in one for further exploratory data analysis

happydemocracygeomerge = geomeanLATAMdf.merge(Happy, left_on='country', right_on='Country')
happydemocracygeomerge.head(1)
# Out:
#                                             geometry country country_name  \
# 0  MULTIPOLYGON (((-92.86236 15.16819, -92.86236 ...  Mexico       Mexico
#
#    v2x_libdem  v2x_cspart  v2x_rule Country  Happy2015  Happy2016  Happy2017  \
# 0    0.265306    0.414403  0.389516  Mexico      7.187      6.595      6.578
#
#    Happy2018  Happy2019
# 0      6.488      6.595

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 9))
happydemocracygeomerge.plot('Happy2015', ax=ax[0], legend=True, cmap='inferno')
happydemocracygeomerge.plot('Happy2019', ax=ax[1], legend=True, cmap='inferno')

ax[0].set_title("2015 Happiness Scores Across Latin America")
ax[1].set_title("2019 Happiness Scores Across Latin America")

fig.text(.5, .1, "The color bar values for happiness range from 0 (unhappy) to 10 (completely happy)", rotation=270, fontsize=12, weight='bold')
fig.text(.9, .1, "The color bar values for happiness range from 0 (unhappy) to 10 (completely happy)", rotation=270, fontsize=12, weight='bold')

ax[0].set_xticks([])
ax[0].set_yticks([])
ax[1].set_xticks([])
ax[1].set_yticks([])
# Out:
# []

# %% [markdown]
# **Figure 10** plots the happiness scores spatially for Latin American countries with 2015 values plotted on the left panel and 2019 values plotted on the right panel. Overall -- through the 4 years from 2015 to 2019 -- there appears to be a decrease in happiness scores pretty much across the board for Latin AMerican countries as is evident in shifts in their color variaiotn from the values on the color bar.

# %%
fig, ax = plt.subplots(figsize=(10, 5))
happydemocracygeomerge.plot(x='Happy2015', y='v2x_libdem', kind='scatter', ax=ax, color='red', label="2015 Happiness Scores")
happydemocracygeomerge.plot(x='Happy2016', y='v2x_libdem', kind='scatter', ax=ax, color='blue', label='2016 Happiness Scores')
happydemocracygeomerge.plot(x='Happy2017', y='v2x_libdem', kind='scatter', ax=ax, color='green', label='2017 Happiness Scores')
happydemocracygeomerge.plot(x='Happy2018', y='v2x_libdem', kind='scatter', ax=ax, color='black', label='2018 Happiness Scores')
happydemocracygeomerge.plot(x='Happy2019', y='v2x_libdem', kind='scatter', ax=ax, color='purple', label='2019 Happiness Scores')

ax.set_ylabel('Liberal Democracy Score', fontsize=12)
ax.set_xlabel('Happiness Score', fontsize=12)
ax.set_title('Avg Democracy level (1960-2020) as a function of Happiness in Latin America 2015-2019', weight='bold')
# Out:
# Text(0.5, 1.0, 'Avg Democracy level (1960-2020) as a function of Happiness in Latin America 2015-2019')

# %% [markdown]
# **Figure 11** plots the average democracy score for the years 1960-2020 in a scatter plot for the years 2015:2019 of the happiness scores for the corresponding Latin American countries. Put simply -- figure 11 plots average democracy score over time as a function of happiness scores for the year 2015, 2016, 2017, 2018, and 2019 respectively. Overall, We clearly see from the labeled points in red in 2015 that happiness was at its highest levels for many observations whereas for 2019 in purple dots we see that happiness is at its lowest levels for many observations. This is a worrying trend. We do notice here however, the more democracy there is the happier a country appears to be. Suggesting to us a positive correlation is present between the Happiness feature and the liberal democracy target.

# %%
fig, ax = plt.subplots(figsize=(10, 5))
happydemocracygeomerge.plot(x='v2x_rule', y='v2x_libdem', kind='scatter', ax=ax, color='red', label="Avg Rule of Law Strength (1960-2020")
happydemocracygeomerge.plot(x='v2x_cspart', y='v2x_libdem', kind='scatter', ax=ax, color='blue', label="Avg Civil Society Strength (1960-2020")
ax.set_xlabel("")
ax.set_ylabel('Liberal Democracy Score')
ax.set_title('Avg Liberal Democracy as a function of Rule of Law Strength and Civil Soceity Strength', weight='bold', style='italic')
# Out:
# Text(0.5, 1.0, 'Avg Liberal Democracy as a function of Rule of Law Strength and Civil Soceity Strength')

# %% [markdown]
# **Figure 12** plots a scatter plot of avg liberal democracy scores (1960-2020) as a function of avg rule of law strength 1960-2020 shown via red dots and as a function of avg civil society strength 1960-2020 shown via blue dots. Overall, we see a clear positive relationship is present for both features impact on the dependentt variable democracy. The higher up the scale on both rule of law strength and civil society strength -- the more democracy we correspondingly see.

# %% [markdown]
# # **7.Machine Learning**

# %% [markdown]
# ## **I. KMeans Clustering**

# %% [markdown]
# ### **a. Re-Reading in the Data**

# %%
# re-reading in all of the data for main democracy dataset
# reading in the data
fname = "/content/drive/MyDrive/mlpp22/assignments/group1/V-Dem-CY-Core-v12.csv"
democracy = pd.read_csv(fname)

#getting only the columns we want
cols = ['country_name', 'year', 'v2x_libdem', 'v2x_cspart', 'v2x_rule']
democracy = democracy[cols]

# reset the index
democracy = democracy.set_index('country_name')

# drop countries we don't need
countries = ['Palestine/British Mandate', 'Baden', 'Bavaria', 'Modena', 'Parma', 'Saxony', 'Tuscany', 'Würtemberg', 'Two Sicilies', 'Hanover', 'Hesse-Kassel', 'Hesse-Darmstadt', 'Mecklenburg Schwerin', 'Papal States', 'Hamburg', 'Brunswick','Oldenburg', 'Saxe-Weimar-Eisenach', 'Nassau', 'Piedmont-Sardinia', 'Vanuatu', 'Seychelles', 'Sao Tome and Principe', 'Solomon Islands', 'Republic of Vietnam', 'Maldives', 'Palestine/West Bank', 'Eswatini', 'Palestine/Gaza', 'Somaliland', 'Zanzibar']
democracy = democracy.drop(countries)

# reset the index
democracy = democracy.reset_index()

# creating a dataframe for only LATAM countries
democracy = democracy.set_index('country_name')

# making a list of only Latin American countries
DemocracyLatinAmerica = ['Mexico', 'Colombia', 'Brazil', 'El Salvador', 'Bolivia', 'Honduras', 'Peru', 'Argentina', 'Venezuela', 'Nicaragua', 'Chile', 'Costa Rica', 'Ecuador', 'Guatemala', 'Panama', 'Uruguay', 'Dominican Republic', 'Cuba', 'Guyana', 'Paraguay']

# Makign the Latin American country specific dataframe
DemocracyLatinAmerica = democracy.loc[DemocracyLatinAmerica]

# resetting the index
DemocracyLatinAmerica = DemocracyLatinAmerica.reset_index()

# getting values only after 1960
DemocracyLatinAmerica1960 = DemocracyLatinAmerica['year'] >= 1960
DemocracyLatinAmerica1960 = DemocracyLatinAmerica[DemocracyLatinAmerica1960]
DemocracyLatinAmerica1960 = DemocracyLatinAmerica1960.reset_index()
DemocracyLatinAmerica1960 = DemocracyLatinAmerica1960.drop(columns='index')
DemocracyLatinAmerica1960.head(4)
# Out:
#   country_name  year  v2x_libdem  v2x_cspart  v2x_rule
# 0       Mexico  1960       0.106       0.139     0.241
# 1       Mexico  1961       0.106       0.139     0.241
# 2       Mexico  1962       0.107       0.139     0.241
# 3       Mexico  1963       0.107       0.139     0.241

# %% [markdown]
# ### **b. Creating groupby dataframes over time for KMeans Cluster Analysis for our main features and target in the democracy dataframe**

# %%
liberaldemocracyKMeans = DemocracyLatinAmerica1960.groupby(['country_name', 'year']).mean().unstack('year')['v2x_libdem'].dropna()
civilsocietystrengthKMeans = DemocracyLatinAmerica1960.groupby(['country_name', 'year']).mean().unstack('year')['v2x_cspart'].dropna()
ruleoflawstrengthKMeans = DemocracyLatinAmerica1960.groupby(['country_name', 'year']).mean().unstack('year')['v2x_rule'].dropna()

# extracting out the country names from one of the three main KMeans Cluster Datafraes that can serve for all KMeans anlayiss
country = liberaldemocracyKMeans.index.values

## extracting out the years from the three main KMeans Cluster Datafrmaes that can serve for all Kemans analysis
years = liberaldemocracyKMeans.columns.astype(int)

## getting the values to create numpy arrays for our data from our 3 main dataframes above for the KMeans clustering analysis

liberaldemocracyKMeansnp = liberaldemocracyKMeans.values
civilsocietystrengthKMeansnp = civilsocietystrengthKMeans.values
ruleoflawstrengthKMeansnp = ruleoflawstrengthKMeans.values

# %% [markdown]
# ### **c. Standardizing the 3 main clustering dataframes created that contain our target and 2 main features respectively**

# %%
# -- now let's cluster, but first (of course) standardize across columns to
#    cluster based on trends in the time series for all 3 of our main variable dataframes
liberaldemocracyKMeans_st = (liberaldemocracyKMeansnp - liberaldemocracyKMeansnp.mean(axis=1, keepdims=True)) / liberaldemocracyKMeansnp.std(axis=1, keepdims=True)
civilsocietystrengthKMeans_st = (civilsocietystrengthKMeansnp - civilsocietystrengthKMeansnp.mean(axis=1, keepdims=True)) / civilsocietystrengthKMeansnp.std(axis=1, keepdims=True)
ruleoflawstrengthKMeans_st = (ruleoflawstrengthKMeansnp - ruleoflawstrengthKMeansnp.mean(axis=1, keepdims=True)) / ruleoflawstrengthKMeansnp.std(axis=1, keepdims=True)

# %% [markdown]
# ### **d. Using the "Elbow Method" to determine the optimal 'K'**

# %%
# import the KMeans clustering algorithm
from sklearn.cluster import KMeans

# %% [markdown]
# First -- I am employing the elbow method to find out the optimal K (# of clusters to use for our 3 variables of interest)  **From the plots below for our 3 variables of interest -- a K = 3 appears optimal for all 3 series (our target: liberal democracy; and 2 feauures (Rule of Law Strength & Civil Society Strength respectively)**

# %%
# Liberal Democracy elbow method
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(liberaldemocracyKMeans_st)
    distortions.append(kmeanModel.inertia_)

fig, ax = plt.subplots(figsize=(10,5))

ax.plot(K, distortions, 'bx-')
ax.set_xlabel('k')
ax.set_ylabel('Distortion')
ax.set_title('Elbow Method Liberal Democracy Optimal K')
plt.show()

# civil soceity strength elbow method
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(civilsocietystrengthKMeans_st)
    distortions.append(kmeanModel.inertia_)

fig, ax = plt.subplots(figsize=(10,5))

ax.plot(K, distortions, 'bx-')
ax.set_xlabel('k')
ax.set_ylabel('Distortion')
ax.set_title('Elbow Method Civil Society Strength Optimal K')
plt.show()

# rule of law strength elbow method
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(ruleoflawstrengthKMeans_st)
    distortions.append(kmeanModel.inertia_)

fig, ax = plt.subplots(figsize=(10,5))

ax.plot(K, distortions, 'bx-')
ax.set_xlabel('k')
ax.set_ylabel('Distortion')
ax.set_title('Elbow Method Rule of Law Strength Optimal K')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# **Figure 1: Presents the output plotted images of running the Elbow Method to find the optimal level of K clusters for our unsupervised algorithm. For all 3 series -- a K of 3 appears optimal as is evidenced by the breaking of the "elbow" along the x-axis 'k' values at the value of 3.**

# %% [markdown]
# ### **e. Running our KMeans Clustering Algorithm**
#
# ---
#
#
#
# ---

# %%
# -- cluster with 3 clusters

# instantiate & fit liberal democracy
kmliberaldemocracy = KMeans(n_clusters=3).fit(liberaldemocracyKMeans_st)

# instantiate & fit civil soceity strength
kmcivilsocietystrength = KMeans(n_clusters=3).fit(civilsocietystrengthKMeans_st)

# instantiate & fit rule of law strength
kmruleoflawstrength = KMeans(n_clusters=3).fit(ruleoflawstrengthKMeans_st)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ### **f. KMeans Cluster Results, Interpretation, & Visualization**

# %%
# plot the cluster centers for our 3 models

# -- plot the cluster centers
fig, ax = plt.subplots(1, 3, figsize=(20, 5))

libdem = ax[0].plot(years, kmliberaldemocracy.cluster_centers_.T)
ax[0].set_xlabel("Year")
ax[0].set_ylabel("Liberal Democracy Score \n[standardized units]")
ax[0].legend(libdem, ["cluster 0", "cluster 1", "cluster 2"])
ax[0].set_title('Panel 1: Liberal Democracy Cluster Centers')
fig.show()


civsociety = ax[1].plot(years, kmcivilsocietystrength.cluster_centers_.T)
ax[1].set_xlabel("Year")
ax[1].set_ylabel("Civil Society Strength Score \n[standardized units]")
ax[1].legend(civsociety, ["cluster 0", "cluster 1", "cluster 2"])
ax[1].set_title('Panel 2: Civ Society Strength Cluster Centers')
fig.show()


ruleoflaw = ax[2].plot(years, kmruleoflawstrength.cluster_centers_.T)
ax[2].set_xlabel("Year")
ax[2].set_ylabel("Rule of Law Strength Score \n[standardized units]")
ax[2].legend(ruleoflaw, ["cluster 0", "cluster 1", "cluster 2"])
ax[2].set_title('Panel 3: Rule of Law Strength Cluster Centers')
fig.show()

# %% [markdown]
# **Figure 2 plots our 3 cluster centers our KMeans clustering algorithtm found for our 3 main features of interest: Liberal Democracy in Panel 1 on the left hand side; Civil Society Strength in Panel 2 in the middle; & Rule of Law Strength in Panel 3 on the right hand side.**
#
#
# 1.   **In interpreting Panel 1** the 3 KMeans Cluster centers for Liberal Democracy for countries throughout the Latin American region from 1960-2021: Our algorithm has identified 2 cluster centers of countries that have increased in their liberal democracy scores over time as shown in the blue and purple clusters respectively (cluster 0 and cluster 2). However, the difference between these 2 clusters that our algorithim found is that cluster 0 in blue appears to reach near peak of liberal democracy scores around the year 2000 before dropping off and going into a modest decline. Meanwhile, clsuter 2 in purple appears to capture a trend in Latin American countries that continue to increase their overall levels of liberal democracy past 2000 and all of the ways up until about 2018 until they begin to decline relatively modestly. For cluster 1 shown in red in panel 1 on the left-hand side, our algorithim in this case for cluster 1 picked up a clustering in which Latin American countries have went into a steep democratic decline from nearly 1990 onwards from what otherwise was relatively higher levels of liberal democracy to begin with from 1960 to 1990 relative to cluster 0 and cluster 2. Cluster 1 picked up a clustering then where countries in this cluster center went into a steep demcoratic decline from 1990 onwards until the end of the time period under study (2021). In short, our KMeans clustering algorithm picked up 1 group of countries in Latin America that have strongly "liberal democratized" (cluster 2); that have moderately 'liberal democratized" (cluster 0); & that have sharply declined in their levels of 'Liberal Democracy".
#
# 2. **Interpreting Panel 2 in figure 2**: Panel 2 plots the 3 cluster centers our KMeans algorithm found for our feature "Civil Society Strength". Similar to panel 1 that had 2 similar cluster center with slight varaition, panel 2 also appears to have found the same paterns in our data. For instance, cluster 0 & cluster 1 found clusters of Latin American countries that have increased their civil society strenght over time. However, cluster 0 in blue looks as if it identified a grouping of countries that decreased in civil society strength in Latin America from the 1960s until about the 1980s when the era of authoritarian rule came to an end in Latin AMerica. This is different than cluster 1 in purple which appears to have picked up a grouping of countries that have monotonically increased for the most part their levels of civil society strength from 1960s onwards until 2021. Cluster 2 in purple was the outlier in panel 2 presented in figure 2 above. Cluster 2 picked up a grouping of countries that have had their levels of civil society strength abruptly decline from roughly the 1990s onwards. This finding by our KMeans algorithim is an outlier in terms of the general patterns we see with the other 2 clusters, and it is interesting to note that cluster 2 in purple in panel 2 appears to follow the similar trend as cluster 1 in panel 1 (both of these clusters in their respective panels experienced sharp drop offs in their levels around 1990 onwards.
#
# 3. **Interpreting panel 3 in figure 2** The KMeans cluster centers for panel 3 which looked at rule of law strength appear to show similar trends with respect to our cluster centers in panel 1 and 2. Once again, there are 2 groupings of clusters in panel 3 in this case, (cluster 0 in blue and cluster 2 in purple) that generally have an upward trend from 1960 onwards in terms of increasing their rule of law strength over time for countries in the Latin American region. However, it is again the case that between these 2 clusters (cluster 0 and cluster 2) cluster 0 in blue starts off declining in the 1960s until about the 1980s suggesting to us this cluster picked up a trend of countries who were under authoritarian rule with a weak rule of law and once democratization came to the region -- rule of law strength levels quickly turned around and began to improve. Meanwhile, cluster 2 in purple appears to have picked up a grouping of countries in the Latin American region that remained relatively unaffected from the authoritarian era (from roughly 1960s to 1980s) as this cluster for the most part increases in a monotonic manner throuhgout the series. With respect to cluster 1 in panel 3 shown in red, this cluster center was the outlier in this case similar to the sole cluster centers that were outliers in panel 1 and 2 respectively whereas in the case of panel 3 cluster 1 hown in red, this cluster center picks up a group of countries that largely have a declining rule of law strength over time in Latin America.

# %% [markdown]
# **Creating Geodataframes to plot and visualize the clusters spatially for our 3 features under study**

# %%
## Getting the cluster labels for our 3 dataframe and putting them into their repsective dataframes for our 3 features under analysis
liberaldemocracyKMeans['LibDemClassification'] = kmliberaldemocracy.labels_
civilsocietystrengthKMeans['Civil_Society_Strength_Classification'] = kmcivilsocietystrength.labels_
ruleoflawstrengthKMeans['Rule_Of_Law_Strength_Classification'] = kmruleoflawstrength.labels_

### Merging the geodataframes and the feature dataframes that contain our cluster label for our 3 feature under study
liberaldemocracyKMeans = latamgeos.merge(liberaldemocracyKMeans, left_on='country', right_on=liberaldemocracyKMeans.index)
civilsocietystrengthKMeans = latamgeos.merge(civilsocietystrengthKMeans, left_on='country', right_on=civilsocietystrengthKMeans.index)
ruleoflawstrengthKMeans = latamgeos.merge(ruleoflawstrengthKMeans, left_on='country', right_on=ruleoflawstrengthKMeans.index)

## converting columns of "cluster labels" in our 3 dataframes to string type to plot them spatially w/ Chorploeth maps
liberaldemocracyKMeans['LibDemClassification'] = liberaldemocracyKMeans['LibDemClassification'].astype(str)
ruleoflawstrengthKMeans['Rule_Of_Law_Strength_Classification'] = ruleoflawstrengthKMeans['Rule_Of_Law_Strength_Classification'].astype(str)
civilsocietystrengthKMeans['Civil_Society_Strength_Classification'] = civilsocietystrengthKMeans['Civil_Society_Strength_Classification'].astype(str)

# %%
# A quci look at how the dataframe looks after being merged as was done above (the other two dataframes appear similar to this one shown below)
liberaldemocracyKMeans.head(1)
# Out:
#                                             geometry country   1960   1961  \
# 0  MULTIPOLYGON (((-92.86236 15.16819, -92.86236 ...  Mexico  0.106  0.106
#
#     1962   1963   1964   1965   1966   1967  ...   2013  2014   2015   2016  \
# 0  0.107  0.107  0.106  0.105  0.105  0.107  ...  0.418  0.42  0.419  0.424
#
#    2017   2018   2019   2020   2021  LibDemClassification
# 0  0.43  0.453  0.438  0.412  0.387                     2
#
# [1 rows x 65 columns]

# %%
fig, ax = plt.subplots(1, 3, figsize=(23, 7))
liberaldemocracyKMeans.plot('LibDemClassification', ax=ax[0], legend=True, cmap='plasma')
civilsocietystrengthKMeans.plot('Civil_Society_Strength_Classification', ax=ax[1], legend=True, cmap='plasma')
ruleoflawstrengthKMeans.plot('Rule_Of_Law_Strength_Classification', ax=ax[2], legend=True, cmap='plasma')

ax[0].set_xticks([])
ax[0].set_yticks([])
ax[0].set_title('Panel 1: Lib Dem Clusters Latin America 1960-2021')

ax[1].set_xticks([])
ax[1].set_yticks([])
ax[1].set_title('Panel 2: Civil Society Clusters Latin America 1960-2021')

ax[2].set_xticks([])
ax[2].set_yticks([])
ax[2].set_title('Panel 3: Rule of Law Clusters Latin America 1960-2021')
# Out:
# Text(0.5, 1.0, 'Panel 3: Rule of Law Clusters Latin America 1960-2021')

# %% [markdown]
# **Figure 3 above plots our cluster labels for our Latin American countries for the 3 features under study: Panel 1 Liberal Democracy Clusters on the left; Panel 2 Civil Society Strength Clusters in the middle; & Panel 3 Rule of Law Strength Clusters on the right-hand side of figure 3**. Figure 3 essentially plots the same information as figure 2 above but rather than showing the cluster centers over time and their respective cluster labels for the Latin American countries under study, figure 3 plots the cluster labels for our 3 different clusters ('k') for our 3 different features under study in a spatial manner to visualize the cluster variation spatially.
#
#
#
# 1.   **Beginning with Panel 1 in figure 3**: Cluster 0 is plotted in blue. This grouping of clusters coincides with cluster 0 in figrue 2 in panel 1 that showed a monotonic increase in levels of liberal democracy. Cluster 2 in yellow also represents countries that increased their levels of liberal democracy over time while cluster 1 shown in pink presents our outlier. This is the important piece of information to take away from panel 1 in figrue 3: Cluster 1 in pink is the outlier and it appears that Venezuela (which is the country represneted in figure 3 panel 1 cluster 1 in pink is that outlier that showed a steep drop in liberal democracy levels ever since the 1990s.
#
# 2. **In Panel 2 in figure 3 we plot a choropleth of cluster labels for Latin American countries for levels of civil society strength**: Cluster 0 and Cluster 1 in blue and pink represen cluster labels and their respective countries that have increased levels of civil society strength in general over time. Cluster 2 as shown in yellow presents our outlier and similar to cluster 1 in panel 1 -- it contains Venezuela -- but also the addition of Cuba which is also plotted in yellow to correspond to cluster 2. Thus, Cuba & Venezuela continue to be outliers for our features under study.
#
# 3. **In Panel 3 in figure 3 we plot a choropleth of cluster labels for Latin American countreis for levels of rule of law strength.** Panel 3 is interesting in what is shows spatially -- as cluster 0 shown in blue by and large represents the majority of Latin American countries that have increased their rule of law strength over time. Cluster 1 shown in pink in panel 3 figure 3 again presents our major outlier relative to the other 2 clusters. Once more, both Venezuela and Cuba were the only countries plotted in pink with a cluster label of 1.

# %% [markdown]
# **Figure 4**: **Plotting The Individaul Clusters & Their Members for Liberal Democracy that coincides with the findings as presented in Figure 2 panel 1 & Figure 3 panel 1 above**. The plots presented below correspond in order as you scroll for cluster 0, cluster 1, and cluster 2 respectively and prints out the country member names that belong to each of these repective clusters.

# %%
# -- plot each cluster individually and its members
for cnum in range(kmliberaldemocracy.n_clusters):

  # -- True/False index of where label_ is cnum
  ind = kmliberaldemocracy.labels_ == cnum

  # -- get the members of that cluster number
  mems = liberaldemocracyKMeans_st[ind]

  # -- make a plot
  fig, ax = plt.subplots(figsize=[10, 5])
  ax.plot(years, mems.T, lw=0.2, color="k")
  ax.plot(years, kmliberaldemocracy.cluster_centers_[cnum], color="r")
  ax.set_xlabel("Year")
  ax.set_ylabel("Liberal Democracy Scores \n[standardized units]")
  fig.show()

  # -- refresh screen
  plt.pause(0.01)

  # -- print member countries and extra space
  print("member countries ", country[ind])
  print("\n\n")
# Out:
# member countries  ['Venezuela']
# member countries  ['Argentina' 'Bolivia' 'Brazil' 'Costa Rica' 'Dominican Republic'
#  'Ecuador' 'Honduras' 'Nicaragua']
# member countries  ['Chile' 'Colombia' 'Cuba' 'El Salvador' 'Guatemala' 'Guyana' 'Mexico'
#  'Panama' 'Paraguay' 'Peru' 'Uruguay']

# %% [markdown]
# **Figure 5**: **Plotting The Individaul Clusters & Their Members for Civil Society Strength that coincides with the findings as presented in Figure 2 panel 2 & Figure 3 panel 2 above**. The plots presented below correspond in order as you scroll for cluster 0, cluster 1, and cluster 2 respectively and prints out the country member names that belong to each of these repective clusters.

# %%
# -- plot each cluster individually and its members
for cnum in range(kmcivilsocietystrength.n_clusters):

  # -- True/False index of where label_ is cnum
  ind = kmcivilsocietystrength.labels_ == cnum

  # -- get the members of that cluster number
  mems = civilsocietystrengthKMeans_st[ind]

  # -- make a plot
  fig, ax = plt.subplots(figsize=[10, 5])
  ax.plot(years, mems.T, lw=0.2, color="k")
  ax.plot(years, kmcivilsocietystrength.cluster_centers_[cnum], color="r")
  ax.set_xlabel("Year")
  ax.set_ylabel("Civil Society Strength \n[standardized units]")
  fig.show()

  # -- refresh screen
  plt.pause(0.01)

  # -- print member countries and extra space
  print("member countries ", country[ind])
  print("\n\n")
# Out:
# member countries  ['Cuba' 'Venezuela']
# member countries  ['Argentina' 'Bolivia' 'Chile' 'Guyana' 'Honduras' 'Peru' 'Uruguay']
# member countries  ['Brazil' 'Colombia' 'Costa Rica' 'Dominican Republic' 'Ecuador'
#  'El Salvador' 'Guatemala' 'Mexico' 'Nicaragua' 'Panama' 'Paraguay']

# %% [markdown]
# **Figure 6**: **Plotting The Individaul Clusters & Their Members for Rule of Law Strength that coincides with the findings as presented in Figure 2 panel 3 & Figure 3 panel 3 above**. The plots presented below correspond in order as you scroll for cluster 0, cluster 1, and cluster 2 respectively and prints out the country member names that belong to each of these repective clusters.

# %%
# -- plot each cluster individually and its members
for cnum in range(kmruleoflawstrength.n_clusters):

  # -- True/False index of where label_ is cnum
  ind = kmruleoflawstrength.labels_ == cnum

  # -- get the members of that cluster number
  mems = ruleoflawstrengthKMeans_st[ind]

  # -- make a plot
  fig, ax = plt.subplots(figsize=[10, 5])
  ax.plot(years, mems.T, lw=0.2, color="k")
  ax.plot(years, kmruleoflawstrength.cluster_centers_[cnum], color="r")
  ax.set_xlabel("Year")
  ax.set_ylabel("Rule of Law Strength \n[standardized units]")
  fig.show()

  # -- refresh screen
  plt.pause(0.01)

  # -- print member countries and extra space
  print("member countries ", country[ind])
  print("\n\n")
# Out:
# member countries  ['Brazil' 'Chile' 'Colombia' 'Costa Rica' 'El Salvador' 'Guatemala'
#  'Mexico' 'Panama' 'Paraguay' 'Uruguay']
# member countries  ['Cuba' 'Guyana' 'Venezuela']
# member countries  ['Argentina' 'Bolivia' 'Dominican Republic' 'Ecuador' 'Honduras'
#  'Nicaragua' 'Peru']

# %% [markdown]
# ### **g. KMeans Cluster Problem Solution -- Latin American Region**

# %% [markdown]
# After running our KMeans clustering algorithm for the Latin American region overall -- it is apparent that for our current data under study in which we have analyzed here our 3 principal features in the Main Democracy Dataframe to include 1. Liberal Dmeocracy Score; 2. Civil Society Strength; & 3. Rule of Law Strength -- that there are distinct clusters and groupings of Latin American countries for these 3 features.
#
#
#
# *   For one, our KMeans clustering algorithm identified that a 'k' of 3 was optimal for each of the 3 features mentioned above in our unsupervised learning KMeans Clustering in which we attempted to understand patterns and trends in our data.
#
# *  It is also clear from our KMeans Clustering unsupervised learning algorithm for the Latin Americnan region, that our algorithm picked up 2 key clusters and their trends for all 3 of these features. In one of these trends, our algorithm identfieid cluster centers and their country members that were impacted by the authoritarian era in Latin America where the values of our 3 features declined from roughly 1960 to 1980 and then increased again once democratization began occurring throughout the region. The other key cluster center trend it picked up was a trend with cluster members that did not necearily be as heavily impacted by the authoritarian era in Latin America and rather gradually increased over time from 1960 onwards for all 3 of our features.
#
# * Finally, our unsupervsied learning algorithm KMeans clustering for the Latin American region time and again for our 3 features under study (Liberal Democracy; Civil Society Strength; & Rule of Law Strength) picked up a cluster grouping that was an outlier relative to the other 2 cluster goupings that included one or both of the following countrie: Venezuela & Cuba. These countries were outliers in the fact that in contrary to the other 2 cluster groups, the cluster group that included either on or both of these countries was always negative in nature in term of its trend. Suggesting to us that for the most part -- Latin American countries across the board have strengthened their levels and improved over time in all 3 of our key features except for both Cuba & Venezuela.
#
#
#
# *  In conclusion, it poses a problem that both Cuba & Venezuela remain key outliers in a negative sense for their levels of democracy, civil society strength, and rule of law strength respectively. International organizations and democratic nations around the world should continue to engage in dialogue with both of these countries while proposing measures that would aid them and their populace to democratize and overthrow the current authoritarian regimes present in both of these countries. It will also be important for policymakers moving forward with respect to liberal democracy feature especially to understand why it was in Figure 2 panel 1, that we had 1 cluster (cluster 0 in blue & its members) that stopped increasing in its levels of liberal democracy around the year 2000 in contrast to cluster 2 in purple and its members which continue the trend of increasing in its liberal democracy scores. Policymakers and academics alike should analyze in greater depth the difference of member between these two clusters to undestand why increasing liberal democracy scores came to a halt in cluster 0 but continued to increase in cluster 2 after the year 2000. Doing so will be beneficial for understanding why democratic progress halted in some countries of the region but continued in others. To do so in this study, however, is beyond the scope of this analysis.

# %% [markdown]
# ## **II. Logistic Regression**

# %% [markdown]
# ### **a. Feature Engineering & Dataframe Creation**

# %%
#######################
## FIRST FEATURE ENGINEERING THE LIBERAL DEMOCRACY DATASET ##
#######################

# getting data only on or after year 2015 to merge with the Happiness data that is between 2015 through 2019
new2015 = DemocracyLatinAmerica1960['year'] >= 2015
# boolean indexing it and creating new dataframe through masking operations
DemocracyLatinAmerica2015_2019 = DemocracyLatinAmerica1960[new2015]
# getting data only on or before 2019
new2019 = DemocracyLatinAmerica2015_2019['year'] <= 2019
# boolean indexing it for the final dataframe with years between 2015 and 2019 & masking operations to execute
DemocracyLatinAmerica2015_2019 = DemocracyLatinAmerica2015_2019[new2019]

#######################
## SECOND FEATURE ENGINEERING THE HAPPINESS DATASET ##
######################

# preparing the Happiness dataframe to make it pooled across years for logistic regression
HappyT = Happy.T
# replacing the transposed data columns with country names
Country = HappyT.loc['Country'].to_list()
HappyT.columns = Country
# dropping the prior column of country names
HappyT = HappyT.drop(labels='Country')

# creating a column for year in order to line up with democracy dataframe
years = [2015, 2016, 2017, 2018, 2019]
# adding it tO the happiness dataframe
HappyT['year'] = years
# dropping the old index that is now a column and resetting the index
HappyT = HappyT.reset_index().drop(columns='index')
HappyT
# Out:
#   Mexico Colombia Brazil El Salvador Bolivia Honduras   Peru Argentina  \
# 0  7.187    6.477  6.983        6.13    5.89    4.788  5.824     6.574
# 1  6.595    6.125    6.3       6.253   5.779     5.86  5.697     6.086
# 2  6.578    6.357  6.635       6.003   5.823    5.181  5.715     6.599
# 3  6.488     6.26  6.419       6.167   5.752    5.504  5.663     6.388
# 4  6.595    6.125    6.3       6.253   5.779     5.86  5.697     6.086
#
#   Venezuela Nicaragua  Chile Costa Rica Ecuador Guatemala Panama Uruguay  \
# 0      6.81     5.828   6.67      7.226   5.975     6.123  6.786   6.485
# 1     4.707     6.105  6.444      7.167   6.028     6.436  6.321   6.293
# 2      5.25     6.071  6.652      7.079   6.008     6.454  6.452   6.454
# 3     4.806     6.141  6.476      7.072   5.973     6.382   6.43   6.379
# 4     4.707     6.105  6.444      7.167   6.028     6.436  6.321   6.293
#
#   Dominican Republic Paraguay  year
# 0              4.885    5.878  2015
# ...

# %%
## Taking the HappyT dataframe created and shown above and creating a new dataframe that has all countrie and their happiness scores per year in 2 columns in a pooled time series like structure
Happy2015_2019 = HappyT['Mexico'].append(HappyT['Colombia']).append(HappyT['Brazil']).append(HappyT['El Salvador']).append(HappyT['Bolivia']).append(HappyT['Honduras']).append(HappyT['Peru']).append(HappyT['Argentina']).append(HappyT['Venezuela']).append(HappyT['Nicaragua']).append(HappyT['Chile']).append(HappyT['Costa Rica']).append(HappyT['Ecuador']).append(HappyT['Guatemala']).append(HappyT['Panama']).append(HappyT['Uruguay']).append(HappyT['Dominican Republic']).append(HappyT['Paraguay'])
Happy2015_2019 = pd.DataFrame(Happy2015_2019)
Happy2015_2019

# Now we will recreate our pooled countries as a series and append it to the Happy2015_2019 dataframe for proper construction to get a dataframe with countries, years, and happiness scores in a pooled time series structure
Mexico = ['Mexico'] * 5
Colombia = ['Colombia'] * 5
Brazil = ['Brazil'] * 5
El_Salvador = ['El Salvador'] * 5
Bolivia = ['Bolivia'] * 5
Honduras = ['Hondruas'] * 5
Peru = ['Peru'] * 5
Argentina = ['Argentina'] * 5
Venezuela = ['Venezuela'] * 5
Nicaragua = ['Nicaragua'] * 5
Chile = ['Chile'] * 5
Costa_Rica = ['Costa Rica'] * 5
Ecuador = ['Ecuador'] * 5
Guatemala = ['Guatemala'] * 5
Panama = ['Panama'] * 5
Uruguay = ['Uruguay'] * 5
Dominican_Republic = ['Dominican Republic'] * 5
Paraguay = ['Paraguay'] * 5

# creating the country series from the 'country' lists created above 5 times for each country to represent 5 years of data (2015-2019)
country = pd.DataFrame(Mexico).append(Colombia).append(Brazil).append(El_Salvador).append(Bolivia).append(Honduras).append(Peru).append(Argentina).append(Venezuela).append(Nicaragua).append(Chile).append(Costa_Rica).append(Ecuador).append(Guatemala).append(Panama).append(Uruguay).append(Dominican_Republic).append(Paraguay)

# adding the country series to the Happiness dataset
Happy2015_2019['country'] = country
# changing the column names
Happy2015_2019.columns = ['Happiness Score', 'country']
# re-setting the index
Happy2015_2019 = Happy2015_2019.reset_index()
# dropping the old index value
Happy2015_2019 = Happy2015_2019.drop(columns='index')
# The final Happiness dataframe to be merged now with the constructed democracy dataframe 2015-2019
Happy2015_2019
# Out:
# <ipython-input-43-d4b844577dbc>:2: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Happy2015_2019 = HappyT['Mexico'].append(HappyT['Colombia']).append(HappyT['Brazil']).append(HappyT['El Salvador']).append(HappyT['Bolivia']).append(HappyT['Honduras']).append(HappyT['Peru']).append(HappyT['Argentina']).append(HappyT['Venezuela']).append(HappyT['Nicaragua']).append(HappyT['Chile']).append(HappyT['Costa Rica']).append(HappyT['Ecuador']).append(HappyT['Guatemala']).append(HappyT['Panama']).append(HappyT['Uruguay']).append(HappyT['Dominican Republic']).append(HappyT['Paraguay'])
# <ipython-input-43-d4b844577dbc>:2: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# Now we will merge the constructed 2015-2019 democracy dataset and the happiness dataset constructed together. **But first, We have to drop Cuba and Guyana from the Democracy Dataset** first to correpsond to the Happiness Dataset

# %%
# getting the boolean index for all countries in democracy dataset to mask out Cuba & Guyana
noCubaGuyana = DemocracyLatinAmerica2015_2019['country_name'].isin(['Cuba', 'Guyana'])
## Boolean masking to get our new dataframe without countries: Cuba and Guyana in column = 'country_name
DemocracyLatinAmerica2015_2019 = DemocracyLatinAmerica2015_2019[~noCubaGuyana]
# re-setting the index
DemocracyLatinAmerica2015_2019 = DemocracyLatinAmerica2015_2019.reset_index()
# dropping the old index value
DemocracyLatinAmerica2015_2019 = DemocracyLatinAmerica2015_2019.drop(columns='index')
# re-naming the columns
DemocracyLatinAmerica2015_2019.columns = ['country', 'year', 'liberal_democracy', 'civil_society_strength', 'rule_of_law_strength']
DemocracyLatinAmerica2015_2019

######################################################################################
### Now lets merge the democracy 2015:2019 and happiness 2015:2019 constructed dataframes
#####################################################################################

# merging the 2 dataframes together
HappyDemocracy2015_2019 = pd.merge(DemocracyLatinAmerica2015_2019, Happy2015_2019, left_index=True, right_index=True)
# dropping the exces country variable
HappyDemocracy2015_2019 = HappyDemocracy2015_2019.drop(columns='country_y')
# renaming the country variable
HappyDemocracy2015_2019 = HappyDemocracy2015_2019.rename(columns={'country_x':'country'})
# making Happiness Score an float dtype
HappyDemocracy2015_2019['Happiness Score'] = HappyDemocracy2015_2019['Happiness Score'].astype(float)
# the final merged aataframe
HappyDemocracy2015_2019
# Out:
#      country  year  liberal_democracy  civil_society_strength  \
# 0     Mexico  2015              0.419                   0.604
# 1     Mexico  2016              0.424                   0.618
# 2     Mexico  2017              0.430                   0.676
# 3     Mexico  2018              0.453                   0.678
# 4     Mexico  2019              0.438                   0.524
# ..       ...   ...                ...                     ...
# 85  Paraguay  2015              0.421                   0.597
# 86  Paraguay  2016              0.423                   0.597
# 87  Paraguay  2017              0.418                   0.592
# 88  Paraguay  2018              0.417                   0.585
# 89  Paraguay  2019              0.419                   0.596
#
#     rule_of_law_strength  Happiness Score
# 0                  0.470            7.187
# 1                  0.470            6.595
# 2                  0.474            6.578
# 3                  0.474            6.488
# ...

# %% [markdown]
# ### **b. Summary Plots & Exploratory Data Analysis for Logistic Regression | To determine any additional Features Engineering**

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize=(10, 5))
HappyDemocracy2015_2019[['liberal_democracy', 'civil_society_strength', 'rule_of_law_strength', 'Happiness Score']].hist(ax=ax, bins=15)
# Out:
# <ipython-input-46-4298e8a56518>:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   HappyDemocracy2015_2019[['liberal_democracy', 'civil_society_strength', 'rule_of_law_strength', 'Happiness Score']].hist(ax=ax, bins=15)
# array([[<Axes: title={'center': 'liberal_democracy'}>,
#         <Axes: title={'center': 'civil_society_strength'}>],
#        [<Axes: title={'center': 'rule_of_law_strength'}>,
#         <Axes: title={'center': 'Happiness Score'}>]], dtype=object)

# %% [markdown]
# **Figure 1** Plots histograms of our 4 3 main features (Rule of Law strength; Happiness Score; & Civil Society Strength) along with our target (Liberal Democracy). Overall, the various features do not appear to follow a normal distribution. With that said, however, there do not appear to be any extreme outliers for any of these features on the lower or upper bounds of their respective values.

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
HappyDemocracy2015_2019.plot('civil_society_strength', 'liberal_democracy', kind='scatter', ax=ax[0], color='r', label="Civil Society Strength")
HappyDemocracy2015_2019.plot('rule_of_law_strength', 'liberal_democracy', kind='scatter', ax=ax[0], label='Rule of law Strength')

HappyDemocracy2015_2019.plot('Happiness Score', 'liberal_democracy', kind='scatter', ax=ax[1], label='Happiness Score')

ax[0].set_ylabel('Liberal Democracy')
ax[0].set_xlabel("")
ax[1].set_ylabel('Liberal Democracy')
ax[1].set_xlabel("")
ax[0].set_title('Panel 1')
ax[1].set_title('Panel 2')
# Out:
# Text(0.5, 1.0, 'Panel 2')

# %% [markdown]
# **Figure 2** plots scatterplots on the left panel in panel 1 of rule of law strength in blue dots and civil society strength in red dots on liberal democracy (on the y-axis). In the right side panel in panel 2 it plots Happiness Scores in blue dots on liberal democracy (on the y-axis). On the Left panel in panel 1 -- rule of Law Strength & Civil Society Strength appear to have fairly strong positive correlations with liberal democray. Given this insight and the fact that both appear to move in tandem with respect to liberal democracy values in the sense that thee feature increase as the level of liberal democracy increase -- I will interact these two features to create an interaction term.

# %%
### Creating the interaction term for rule of law X Civil Society
HappyDemocracy2015_2019['Rule of Law X Civil Society'] = HappyDemocracy2015_2019['civil_society_strength'] * HappyDemocracy2015_2019['rule_of_law_strength']

# %% [markdown]
# ### **c. Constructing the target variable & visualizing it (dichotomizing liberal democracy to 0 - 1 outcome for logistic regression)**

# %% [markdown]
# In order to create our target variable "liberal democracy" to be able to run in a logistic regression, we need to transform it from its continous form by dichotomizing it so it takes on a value of 1 and or 0. For purposes of this analysis and as is shown below in the code: I took any observation that had a value of 0.51 or greater for liberal democracy target and coded it as a 1 to repreent a country that is a "Democracy" (Even if it is a weak democracy as is represented if the values are near the cutoff of 0.51). Any feature that was less than 0.51 -- I coded it as a 0 to represet a country that is a non-Democracy.

# %%
# creating a for loop and an empty list to create a new variable for 0-1 democracy outcome
Democracy_Outcome = []
for ii in HappyDemocracy2015_2019['liberal_democracy']:
  if ii >= 0.51:
    ii = 1
  else:
    ii = 0
  Democracy_Outcome.append(ii)

# adding the new democracy_outcome variable to the existing dataframe
HappyDemocracy2015_2019['Democracy_Outcome'] = Democracy_Outcome
HappyDemocracy2015_2019
# Out:
#      country  year  liberal_democracy  civil_society_strength  \
# 0     Mexico  2015              0.419                   0.604
# 1     Mexico  2016              0.424                   0.618
# 2     Mexico  2017              0.430                   0.676
# 3     Mexico  2018              0.453                   0.678
# 4     Mexico  2019              0.438                   0.524
# ..       ...   ...                ...                     ...
# 85  Paraguay  2015              0.421                   0.597
# 86  Paraguay  2016              0.423                   0.597
# 87  Paraguay  2017              0.418                   0.592
# 88  Paraguay  2018              0.417                   0.585
# 89  Paraguay  2019              0.419                   0.596
#
#     rule_of_law_strength  Happiness Score  Rule of Law X Civil Society  \
# 0                  0.470            7.187                     0.283880
# 1                  0.470            6.595                     0.290460
# ...

# %% [markdown]
# **Visualizing the newly constructed target (0 or 1 outcome) with our main features for the logistic regression.**

# %%
# -- let's consider our features

fig, ax = plt.subplots(1, 4, figsize=[20, 4])

ax[0].scatter(HappyDemocracy2015_2019["rule_of_law_strength"], HappyDemocracy2015_2019["Democracy_Outcome"], color="k", alpha=0.2)
ax[0].set_xlabel("Rule of Law Strength")
ax[0].set_ylabel("Outcome [1=Democracy, 0=Non-Democracy]")
fig.show()

ax[1].scatter(HappyDemocracy2015_2019["civil_society_strength"], HappyDemocracy2015_2019["Democracy_Outcome"], color="k", alpha=0.2)
ax[1].set_xlabel("Civil Society Strength")
ax[1].set_ylabel("Outcome [1=Democracy, 0=Non-Democracy]")
fig.show()


ax[2].scatter(HappyDemocracy2015_2019["Rule of Law X Civil Society"], HappyDemocracy2015_2019["Democracy_Outcome"], color="k", alpha=0.2)
ax[2].set_xlabel("Rule of Law Strength X Civ Society Strength")
ax[2].set_ylabel("Outcome [1=Democracy, 0=Non-Democracy]")
fig.show()


ax[3].scatter(HappyDemocracy2015_2019["Happiness Score"], HappyDemocracy2015_2019["Democracy_Outcome"], color="k", alpha=0.2)
ax[3].set_xlabel("Happiness Score")
ax[3].set_ylabel("Outcome [1=Democracy, 0=Non-Democracy]")
fig.show()

ax[0].set_title('Panel 1')
ax[1].set_title('Panel 2')
ax[2].set_title('Panel 3')
ax[3].set_title('Panel 4')
# Out:
# Text(0.5, 1.0, 'Panel 4')

# %% [markdown]
# **Figure 3** Above plots a 4 panel scatterplot of our main features and target (Democracy Outcome). Panel 1 presents a scatter plot of rule of law strength on the x-axis and democracy outcome on the y-axis. Panel 2 presents civil society strength on the x-axis and democracy outcome on the y-axis. Panel 3 presents Rule of Law Strength X Civil Society Strength Interaction term on the x-axis and democracy outcome on the y-axis. Panel 4 presents Happiness Score on the x-axis and demcoracy outcome on the y-axis. Overall, figure 3 is helpful for visualizing the distribution of 0s and 1s for our respective features.
#
# * In terms of what it tells us, it appears almost every rule of law strength value beyond 0.55 on the x-axis in panel 1 has a 1 of democracy outcome. Suggesting to us higher values of rule of law strength coincide with (1) democracy ocutcome and lower values of rule of law strength coincide with non democracy (0 outcome).
#
# * For Panel 2 exmaining civil society strength on democracy outcome, the outcome is a lot less certain. Across the range of values on the x-axis for civil society strength from its minimum to its maximum values, it looks as if countries can still be found to be with a 0 outcome even at high leels of civil society strength. However, any value below 0.6 in panel 2 for civil society strength does not demonstrate an outcome of 1 (democracy) according to our current distribution. Thus, civil society strength across its range of values appears to take on values of 0 indiscriminately but only takes on values of 1 at the upper end of the features values.
#
# * Panel 3 looks at our interaction term Rule of Law Strength X Civil Society Strength on our democracy outcome variable. It is clear that higher values of this feature correspond to an outcome of 1 while lower values correspond to an outcome of 0.
#
# * Panel 4 examines Happiness Scores on our democracy outcome variable. Overall, it appears that regardless of the value of happiness scores -- there is an outcome of 0 suggesting that whether or not countries are overall more or less happy doesn't necessarily show a correlation with demoracy outcome of 1 so to say. However, there are no lower values of happiness on the x-axis that correspond to an outcome of 1 -- only values on the upper bound of the feature correpond to a value of 1.

# %% [markdown]
# ### **d. Logistic Regression Machine Learning Output, Interpretation, & Visualization**

# %%
#########################
#########################
### FITTING LOGIT FOR RULE OF LAW STRENGTH ON DEMOCRACY OUTCOME
########################
########################

# -- let's fit a logistic regression model to this data
from sklearn.linear_model import LogisticRegression

# -- define features and target
XXrule = HappyDemocracy2015_2019['rule_of_law_strength'].values.copy()
YYDemocracy = HappyDemocracy2015_2019['Democracy_Outcome'].values.copy()

# -- initialize the model
lrrule = LogisticRegression()

# -- fit the model to data
lrrule.fit(XXrule.reshape(-1, 1), YYDemocracy)


# -- get predicted values
predrule  = lrrule.predict(XXrule.reshape(-1, 1))

# -- get model values
xvalrule = np.linspace(XXrule.min(), XXrule.max(), 100)
mmrule = lrrule.coef_[0][0]
bbrule = lrrule.intercept_[0]
zrule = xvalrule * mmrule + bbrule
modelrule = 1.0 / (1.0 + np.exp(-zrule))


#########################
#########################
### FITTING LOGIT FOR CIVIL SOCIETY STRENGTH ON DEMOCRACY OUTCOME
########################
########################


# -- let's fit a logistic regression model to this data

# -- define features and target
XXcivil = HappyDemocracy2015_2019['civil_society_strength'].values.copy()
YYDemocracy = HappyDemocracy2015_2019['Democracy_Outcome'].values.copy()

# -- initialize the model
lrcivil = LogisticRegression()

# -- fit the model to data
lrcivil.fit(XXcivil.reshape(-1, 1), YYDemocracy)


# -- get predicted values
predcivil = lrcivil.predict(XXcivil.reshape(-1, 1))

# -- get model values
xvalcivil = np.linspace(XXcivil.min(), XXcivil.max(), 100)
mmcivil = lrcivil.coef_[0][0]
bbcivil = lrcivil.intercept_[0]
zcivil = xvalcivil * mmcivil + bbcivil
modelcivil = 1.0 / (1.0 + np.exp(-zcivil))


#########################
#########################
### FITTING LOGIT FOR CIVIL SOCIETY STRENGTH X RULE OF LAW STRENGTH INTERACTION TERM ON DEMOCRACY OUTCOME
########################
########################

# -- let's fit a logistic regression model to this data

# -- define features and target
XXcivil_rule = HappyDemocracy2015_2019['Rule of Law X Civil Society'].values.copy()
YYDemocracy = HappyDemocracy2015_2019['Democracy_Outcome'].values.copy()

# -- initialize the model
lrcivil_rule = LogisticRegression()

# -- fit the model to data
lrcivil_rule.fit(XXcivil_rule.reshape(-1, 1), YYDemocracy)


# -- get predicted values
predcivil_rule = lrcivil_rule.predict(XXcivil_rule.reshape(-1, 1))

# -- get model values
xvalcivil_rule = np.linspace(XXcivil_rule.min(), XXcivil_rule.max(), 100)
mmcivil_rule = lrcivil_rule.coef_[0][0]
bbcivil_rule = lrcivil_rule.intercept_[0]
zcivil_rule = xvalcivil_rule * mmcivil_rule + bbcivil_rule
modelcivil_rule = 1.0 / (1.0 + np.exp(-zcivil_rule))


#########################
#########################
### FITTING LOGIT FOR HAPPINESS SCORE ON DEMOCRACY OUTCOME
########################
########################


# -- let's fit a logistic regression model to this data

# -- define features and target
XXhappiness = HappyDemocracy2015_2019['Happiness Score'].values.copy()
YYDemocracy = HappyDemocracy2015_2019['Democracy_Outcome'].values.copy()

# -- initialize the model
lrhappiness = LogisticRegression()

# -- fit the model to data
lrhappiness.fit(XXhappiness.reshape(-1, 1), YYDemocracy)


# -- get predicted values
predhappiness = lrhappiness.predict(XXhappiness.reshape(-1, 1))

# -- get model values
xvalhappiness = np.linspace(XXhappiness.min(), XXhappiness.max(), 100)
mmhappiness = lrhappiness.coef_[0][0]
bbhappiness = lrhappiness.intercept_[0]
zhappiness = xvalhappiness * mmhappiness + bbhappiness
modelhappiness = 1.0 / (1.0 + np.exp(-zhappiness))





###################################
# PLOTTING THE LOGISTIC REGRESSIONS
##################################

# -- plot the models and predictions
fig, ax = plt.subplots(1, 4, figsize=[30, 8])

# logistic regression predictions for rule of law strength
ax[0].scatter(XXrule, YYDemocracy, color="k", alpha=0.2)
ax[0].scatter(XXrule, predrule, s=15)
ax[0].plot(xvalrule, modelrule, color="darkorange", lw=3)
ax[0].set_xlabel("Rule of Law Strength", fontsize=15, weight='bold')
ax[0].set_ylabel("Outcome [1=Democracy, 0=Non-Democracy]", fontsize=15, weight='bold')
ax[0].tick_params(axis='x', labelsize=16)
ax[0].tick_params(axis='y', labelsize=16)

# logistic regression predictions for civil society strenth
ax[1].scatter(XXcivil, YYDemocracy, color="k", alpha=0.2)
ax[1].scatter(XXcivil, predcivil, s=15)
ax[1].plot(xvalcivil, modelcivil, color="darkorange", lw=3)
ax[1].set_xlabel("Civil Society Strength", fontsize=15, weight='bold')
ax[1].set_ylabel("Outcome [1=Democracy, 0=Non-Democracy]", fontsize=15, weight='bold')
ax[1].tick_params(axis='x', labelsize=16)
ax[1].tick_params(axis='y', labelsize=16)

# logistic regression predictions for rule of law strength X Civil Society Strength
ax[2].scatter(XXcivil_rule, YYDemocracy, color="k", alpha=0.2)
ax[2].scatter(XXcivil_rule, predcivil_rule, s=15)
ax[2].plot(xvalcivil_rule, modelcivil_rule, color="darkorange", lw=3)
ax[2].set_xlabel("Civil Society Strength X Rule of Law", fontsize=15, weight='bold')
ax[2].set_ylabel("Outcome [1=Democracy, 0=Non-Democracy]", fontsize=15, weight='bold')
ax[2].tick_params(axis='x', labelsize=16)
ax[2].tick_params(axis='y', labelsize=16)


# logistic regression predictions for plotting happiness
ax[3].scatter(XXhappiness, YYDemocracy, color="k", alpha=0.2)
ax[3].scatter(XXhappiness, predhappiness, s=15)
ax[3].plot(xvalhappiness, modelhappiness, color="darkorange", lw=3)
ax[3].set_xlabel("Happiness Score", fontsize=15, weight='bold')
ax[3].set_ylabel("Outcome [1=Democracy, 0=Non-Democracy]", fontsize=15, weight='bold')
ax[3].tick_params(axis='x', labelsize=16)
ax[3].tick_params(axis='y', labelsize=16)

fig.show()

ax[0].set_title('Panel 1: Rule of Law Strength In Sample Preds', weight='bold', fontsize=15)
ax[1].set_title('Panel 2: Civil Society Strength In Sample Preds', weight='bold', fontsize=15)
ax[2].set_title('Panel 3: Law X Civ Soc Strength In Sample Preds', weight='bold', fontsize=15)
ax[3].set_title('Panel 4: Happiness In Sample Preds', weight='bold', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Panel 4: Happiness In Sample Preds')

# %% [markdown]
# **Figure 4** plots a 4 panel plot of in sample predictions of our main features and their impact on our target variable "Democracy Outcome" where each observation in the feature "Liberal Democracy" was given either a 1 to repreent democracy if values were >= 0.51 and a 0 otherwise in its scale of 0 to 1.
#
#
#
# *   Beginning wih panel 1 in figure 4 -- panel 1 on the left hand side of figure 4 plots the in sample predictons for rule of law strength on Democracy Outcome shown in the orange line along with the actual and predicted values in terms of 0 and 1 outcomes seen. Overall, panel 1 shows that as we move across the range of "rule of law strength" on the x-axis -- the probability of being a "democracy" (scoring 0.51 or higher on liberal democracy variable) increases quite sharply as the rule of law strength imrpoves. For a more granular interpretaiton, for countries in Latin America with a rule of law = .2 -- such countries have roughly an 18% probability of being predicted as a democracy (outcome =1) and are therefore much more likely to be predicted as non-democracy (outcome = 0). On the other hand, if we look on the x-axis in panel 1 at a value of .8 for rule of law strength, countries in Latin America that have a rule of law score of .8 out of 1 correspondingly have nearly an 83% chance at being predicted as a democracy (outcome = 1) relative to non-democracy (outcome = 0).
#
# * Panel 2 in figure 4 plots the predicted probabilities for civil society strength feature on our outcome variable. In panel 2, we see that as countrie in the Latin American region increase their levels of civil society strength as shown if we move across the range of the x-axis from left to right, we see a corresponding increase in the predicted probaibliity of a country in Latin America being predicted as a democracy (outcome = 1) relative to non-demcoracy (outcome = 0). However, the magnitude of the effect in terms of the change in % terms of probability of being predicted 1 ( a democracy) is much less than that of rule of law strenght as shown in panel 1 whereas in the case of panel 2, across the entire range of civil society strength -- we only have an increase of about 30% of being predicted a democracy relative to a non-demcoracy from civil soceity strength's minimum to its maximum value on the x-axis. This is in contrast to rule of law strength where across the entire range of rule of law strength in panel 1 from its minimum to its maximum value, there is a correpsnding increase in % terms of being predicted a democracy of nearly 68%.
#
# * Panel 3 plots our interaction term (Rule of law strength X Civil Society strength) on our outcome variable (Democracy outcome). Overall, this feature predicts a strong increase in the probability of being a democracy (outcome = 1; relative to non democracy (outcome = 0)) -- The effect is similar to the effect shown in panel 1 but the magnitude of the effect is slightly less across the range of the features impact on democracy outcome.
#
# * Panel 4 plots our Happiness Score for Latin American countries and its predictions on Democracy Outcome. Ovverall, what panel 4 tells us is that the happier a country gets, the probability of being predicted a democracy( outcome = 1) increase significantly as we move across the range of the variable on the x-axis.
#
# * **In conclusion, from our various panel plots as shown in figure 4 -- it is clear that the rule of law strength matters a great deal for being predicted a democracy (outcome = 1) relative to non-democracy (outcome = 0) as does Happiness. For the variable civil society strength however, the magnitude of the effect is much less pronounced relative to rule of law strength and happiness scores when it comes to predicting an outcome of 1 (democracy) relative to 0 (non-democracy). Nonetheless, the effect is still there -- where greater levels of civil society strenght do show an increased probability of being a given country in Latin America being a democracy relative to non-democracy.**

# %% [markdown]
# ### **e. Logistic Regression Model Evaluation**

# %%
# -- print accuracies and assess accuracies for our various features on our target variable (Democracy_outcome)

acc_rule_of_law = (predrule == YYDemocracy).sum() / len(YYDemocracy)
acc_civil = (predcivil == YYDemocracy).sum() / len(YYDemocracy)
acc_civil_rule = (predcivil_rule == YYDemocracy).sum() / len(YYDemocracy)
acc_happy = (predhappiness == YYDemocracy).sum() / len(YYDemocracy)

print("TABLE 1")
print("")
print("model accuracy rule of law strength predicting Democracy: {0:.2f}".format(acc_rule_of_law))
print("model accuracy civil society strength predicting Democracy: {0:.2f}".format(acc_civil))
print("model accuracy civil society strength X rule of law strength predicting Democracy: {0:.2f}".format(acc_civil_rule))
print("model accuracy happiness predicting Democracy: {0:.2f}".format(acc_happy))
# Out:
# TABLE 1
#
# model accuracy rule of law strength predicting Democracy: 1.00
# model accuracy civil society strength predicting Democracy: 0.70
# model accuracy civil society strength X rule of law strength predicting Democracy: 0.93
# model accuracy happiness predicting Democracy: 0.78

# %% [markdown]
# Table 1 above showcases our various logistic regression model accuracies for our various features on Democracy outcome.
#
# * For rule of law strength, our model (on training data only) predicted democratic outcome (>= 0.51 liberal democracy variable) with a perfect score/accuracy of 1.0 suggesting to us that rule of law strength is a very strong predictor of democracy relative to non-demcracy.
#
# * For our feature civil society strength, our model (on training data) was roughly 70% accurate in predicting democray outcome (1) relative to non-democracy (0) -- suggesting to us that this feature did a fairly decent job at predicting democracy but no where near as robust as rule of law strength.
#
# * For our interaction feature which multiplied civil society strength X rule of law strength -- we see that we have a training accuracy of .93% suggesting to us that this feature did a robust job at predicting correctly whether or not a given country in Latin America was a democracy (1) or not (0).
#
# * For our feature happiness scores, we had an overall training model accuracy overall of 78% when we used this feature to predict democracy (1) relative to non-democracy (0). Overall, this tells us our model did a fairly robust job at predicting democracy.

# %% [markdown]
# ### **f. Logistic Regression Problem Solution**
#
# * In summary, I do not break up this analysis into training and testing splits and thus, the model evaluation presented here in this section for logistic regression is only the model evaluation for the training data (given that we used every observation in the model) and left no data untouched in our attempts to predict democracy. This analysis was carried out this way in order to see and visualize the in-sample predicted probabilities using the full range of our data for the most inclusive results. In the end, what our analysis has shown us along with the model evaluation in assessing the accuracies -- is rule of law strengh relative to all other features is the strongest and most robust predictor of democracy outcome. This suggests to us that countries should focus on strengthening their rule of law above all else in order to increase their chances of becoming a democracy.

# %% [markdown]
# ## **III. Decision Tree Regression Model**

# %% [markdown]
# ### **a. Load in the Pertinent Modules**

# %%
#import our pertinent modules for a random forest regression model
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree
import graphviz
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ### **b. Extract out our Target & Feature Arrays**

# %%
# One hot encode year to add it into the model to see if there is temporal variation in the model have to make it string type
HappyDemocracy2015_2019['year'] = HappyDemocracy2015_2019['year'].astype(str)


# -- pull out the object IDs
country = HappyDemocracy2015_2019["country"]

# -- isolate the features
feat = HappyDemocracy2015_2019.drop(columns=['country', 'Democracy_Outcome', 'liberal_democracy'])

# -- one hot encode
feat = pd.get_dummies(feat)

# -- pull out the target variable
targ = HappyDemocracy2015_2019["liberal_democracy"]

feat
# Out:
#     civil_society_strength  rule_of_law_strength  Happiness Score  \
# 0                    0.604                 0.470            7.187
# 1                    0.618                 0.470            6.595
# 2                    0.676                 0.474            6.578
# 3                    0.678                 0.474            6.488
# 4                    0.524                 0.541            6.595
# ..                     ...                   ...              ...
# 85                   0.597                 0.394            5.878
# 86                   0.597                 0.386            5.743
# 87                   0.592                 0.369            5.493
# 88                   0.585                 0.418            5.681
# 89                   0.596                 0.431            5.743
#
#     Rule of Law X Civil Society  year_2015  year_2016  year_2017  year_2018  \
# 0                      0.283880          1          0          0          0
# ...

# %% [markdown]
# ### **c. Running a base model -- Train & Test a Decision Tree Regression Model | Visualize | Interpretation**

# %%
# -- create a random training and testing set
feat_tr, feat_te, targ_tr, targ_te = train_test_split(feat, targ, test_size=0.2, random_state=63)

# -- fit a decision tree classifier on the TRAINING data
dtc = DecisionTreeRegressor(random_state=63)
dtc.fit(feat_tr, targ_tr)

# -- assess the accuracy on the TRAINING data
pred_tr = dtc.predict(feat_tr)
mae_tr = mean_absolute_error(targ_tr, pred_tr)
print("On Average: Our predictinos for our training data were roughly = {0:.5f} units off".format(mae_tr))

# -- assess the accuracy on the TESTING data
pred_te = dtc.predict(feat_te)
mae_te = mean_absolute_error(targ_te, pred_te)
print("On Average: Our predictions for our testing data were roughly {0:.5f} units off".format(mae_te))
# Out:
# On Average: Our predictinos for our training data were roughly = 0.00000 units off
# On Average: Our predictions for our testing data were roughly 0.02067 units off

# %% [markdown]
# In our base model, we see that our training data fit the model the perfectly and our key metric of interest "mean absolute error" showed fit hte data perfectly in its predictions on the training data as we were 0.000 units off of the true value of what the actual values were. For our testing data, we were on average, about 0.0207 units off of accurately predicting our target variable. However, this model does seem suspect of overfitting given the spread in MAE between our training and testing data. Let us optimize its hyperparameters below -- but first let us visualize the base model predictions.

# %%
from sklearn.metrics import r2_score
# Calculating R^2
print('Our base model has explained roughly 98% of the variation in "liberal democracy" w/ an R^2 value of {0:.3f}'.format(r2_score(targ_te, pred_te)))
# Out:
# Our base model has explained roughly 98% of the variation in "liberal democracy" w/ an R^2 value of 0.982

# %% [markdown]
# Overall, our model has done an excellent job per our R^2 at explaining the variation in liberal democracy values with the features as its inputs.

# %%
# adding in the predictions to visualize them in a separte dataframe with one main feature rule of law strength
feat_viz = feat_te.copy()
feat_viz['predictions'] = pred_te

# -- create importances DataFrame
imp = pd.DataFrame()
imp['feature'] = feat.columns
imp['importances'] = dtc.feature_importances_

# --sort the values from top to least
top = imp.sort_values('importances', ascending=False)[:5]

# -- make the plot
fig, ax = plt.subplots(1, 2, figsize=(20, 5))
top.plot('feature', 'importances', kind='bar', xlabel='', ylabel='feature importance', legend=False, ax=ax[0])
ax[0].set_title("Feature Importances Base Model")
fig.show()


## plotting the actual predictions and

feat_viz.plot('predictions', 'rule_of_law_strength', kind='scatter', ax=ax[1], label='Predicted Values')
ax[1].scatter(targ_te, feat_viz['rule_of_law_strength'], color='green', label='True values')
ax[1].set_ylabel('Rule of Law Strength')
ax[1].set_xlabel('Liberal Democracy Actual & Predicted Values')
ax[1].set_title('Predicted and Actual values of Liberal Democracy on Rule of Law Strength')
ax[1].legend()


## plotting the feature importances

# %% [markdown]
# **Figure 1** plots in the left-hand panel our feature importances for our base model and stemming from the feature importances which it showcased rule of law strength is the feature that matters most for predicting liberal democracy, I created a scatter plot in the right-hand panel showcasing the predicted and actual values of liberal demorcacy on rule of law strength.
#
# * In interpreting the panel on the left hand side that plots feature importances, rule of law strength carries the most weight relative to all other features while our interpretation of the right-hand panel demonstrates that our predicted and actual values were pretty close together suggesting our model did a fairly good job at predicting values of liberal democracy.

# %% [markdown]
# ### **d. Decision Tree Regression Model Robustness -- Finding the decision tree regression model w/ the least mean absolute error**

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

def get_mae(max_leaf_nodes, feat_tr, feat_te, targ_tr, targ_te):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(feat_tr, targ_tr)
    preds_val = model.predict(feat_te)
    mae = mean_absolute_error(targ_te, preds_val)
    return(mae)

# %%
## USING A FOR LOOP TO COMPARE MODELS WITH DIFFERENT MAX LEAF NODES
# compare MAE with differing values of max_leaf_nodes
for max_leaf_nodes in [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 25, 40, 50, 68, 69, 100, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, feat_tr, feat_te, targ_tr, targ_te)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %.5f" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 2  		 Mean Absolute Error:  0.13676
# Max leaf nodes: 3  		 Mean Absolute Error:  0.11924
# Max leaf nodes: 4  		 Mean Absolute Error:  0.06093
# Max leaf nodes: 5  		 Mean Absolute Error:  0.02924
# Max leaf nodes: 6  		 Mean Absolute Error:  0.02774
# Max leaf nodes: 7  		 Mean Absolute Error:  0.02432
# Max leaf nodes: 8  		 Mean Absolute Error:  0.02379
# Max leaf nodes: 9  		 Mean Absolute Error:  0.02015
# Max leaf nodes: 10  		 Mean Absolute Error:  0.02110
# Max leaf nodes: 15  		 Mean Absolute Error:  0.02022
# Max leaf nodes: 25  		 Mean Absolute Error:  0.02275
# Max leaf nodes: 40  		 Mean Absolute Error:  0.02202
# Max leaf nodes: 50  		 Mean Absolute Error:  0.02281
# Max leaf nodes: 68  		 Mean Absolute Error:  0.02256
# Max leaf nodes: 69  		 Mean Absolute Error:  0.02256
# Max leaf nodes: 100  		 Mean Absolute Error:  0.02256
# Max leaf nodes: 500  		 Mean Absolute Error:  0.02256
# Max leaf nodes: 5000  		 Mean Absolute Error:  0.02256

# %% [markdown]
# * From the function above --> the optimal decision tree regression model will have a **max_leaf_nodes of 9** given that it produced the lowest mean absolute error.

# %% [markdown]
# ### **e. Re-Running the Decision Tree Regression Model W/ the Optimal Number of Max Leaf Nodes Found & minimum mean absolute error found | Visualization | Interpretation**

# %%
from sklearn.metrics import r2_score
# -- create a random training and testing set
feat_tr, feat_te, targ_tr, targ_te = train_test_split(feat, targ, test_size=0.2, random_state=63)

# -- fit a decision tree classifier on the TRAINING data
dtc_mod = DecisionTreeRegressor(random_state=63, max_leaf_nodes=9)
dtc_mod.fit(feat_tr, targ_tr)

# -- assess the accuracy on the TRAINING data
pred_tr = dtc_mod.predict(feat_tr)
mae_tr = mean_absolute_error(targ_tr, pred_tr)
print("On Average: Our predictions for our training data were roughly = {0:.5f} units off".format(mae_tr))

# -- assess the accuracy on the TESTING data
pred_te = dtc_mod.predict(feat_te)
mae_te = mean_absolute_error(targ_te, pred_te)
print("On Average: Our predictions for our testing data were roughly {0:.5f} units off".format(mae_te))
# Out:
# On Average: Our predictions for our training data were roughly = 0.02703 units off
# On Average: Our predictions for our testing data were roughly 0.02015 units off

# %% [markdown]
# We see here in interpreting the mean absolute errors for both our training and testing set in our decision tree regression model -- that our model has performed worse off actually rather than our base model, but the spread between the training MAE & testing MAE has narrowed significantly suggesting to us that our model is not being subject to overfiting -- meanwhile, our testing MAE has actually been lowered in the constrianed model suggesting a better generalization of the data the training data was able to pick up on.
#
# **Let's evaluate the feature importances with the more constrained model:**

# %% [markdown]
# **Feature Importance Bar Chart**

# %%
# -- set mpl stylesheet
plt.style.use("bmh")
# -- plot the top 5 "feature importances" (BUT, BE CAREFUL ABOUT INTERPRETATION!)

# -- create importances DataFrame
imp = pd.DataFrame()
imp['feature'] = feat.columns
imp['importances'] = dtc_mod.feature_importances_

# -- select the top 5
top5 = imp.sort_values('importances', ascending=False)[:5]

# -- make the plot
xticks = ['Rule of Law Strength', 'Rule of Law X Civ Soc Strength', 'Happiness Score', 'Civil Society Strength', 'Year 2015']

fig, ax = plt.subplots(figsize=(8, 3))
top5.plot('feature', 'importances', kind='bar', xlabel='', ylabel='feature importance', legend=False, ax=ax)
ax.set_xticklabels(xticks, fontsize=12)
ax.set_ylabel('Feature Importance', fontsize=12)
fig.show()

# %% [markdown]
# **Figure 2** plots the top 5 feature importances for our more constrained model. Once again, rule of law strength is the feature that has the most importance with respect to predicting liberal democracy values.

# %% [markdown]
# **Now let us examine the actual versus fitted values in a scatter plot**

# %%
# creating a dataframe to visualize the actual versus fitted values of liberal democracy from the constrained model
predictions = pd.Series(pred_te)
predictions = predictions.to_list()
actual = targ_te.tolist()


viz = pd.DataFrame(actual)
viz['predictions'] = predictions
viz.columns = ['actual', 'predictions']

# plotting the actual versus constrained values
fig, ax = plt.subplots(figsize=(10, 5))
ax.scatter(targ_te, pred_te, label = 'Actual Values')
ax.scatter(pred_te, targ_te, label = 'Predicted Values')
ax.legend()

# %% [markdown]
# **Figure 3** plots the actual versus predicted values for liberal democracy, overall -- we see that the fit is pretty close to the actual values once again suggesting to us our decision tree regression model fit the data fairly well.

# %% [markdown]
# **Evaluating the constrained model metrics**

# %% [markdown]
# **R^2**

# %%
# Calculating R^2
print('Our constrained model has explained roughly 98% of the variation in "liberal democracy" w/ an R^2 value of {0:.3f}'.format(r2_score(targ_te, pred_te)))
# Out:
# Our constrained model has explained roughly 98% of the variation in "liberal democracy" w/ an R^2 value of 0.983

# %% [markdown]
# * In evaluating our R^2 -- our model fit has actually improved with the constrained model run above that optimized our hyper parameter max_leaf_nodes to = 9; our constrained model here per the R^2 of 0.983 has actually explained more of the variaiton in the liberal democracy values relative to our base model with an R2 of 0.982 (albeit a slight increase). This suggests to us that we have evidence in favor of the more constrained model relative to the more relaxed model.

# %% [markdown]
# ### **f. Robustness Check 2 -- Dealing with Multicollinearity & reducing dimensionality** (Removing the interaction term Civil Society Strength X Rule of Law Strength) | Interpretation | Visualization.

# %%
feat.corr()
# Out:
#                              civil_society_strength  rule_of_law_strength  \
# civil_society_strength                     1.000000              0.697733
# rule_of_law_strength                       0.697733              1.000000
# Happiness Score                            0.284035              0.640912
# Rule of Law X Civil Society                0.767425              0.979457
# year_2015                                  0.059343              0.008058
# year_2016                                  0.030559              0.016096
# year_2017                                  0.008083              0.003174
# year_2018                                 -0.019518             -0.014732
# year_2019                                 -0.078467             -0.012596
#
#                              Happiness Score  Rule of Law X Civil Society  \
# civil_society_strength              0.284035                     0.767425
# rule_of_law_strength                0.640912                     0.979457
# ...

# %% [markdown]
# In examining the correlation matrix above -- it is evident that there is a significant amount of correlation between our interaction term (Rule of Law Strength X Civil Society Strength and both of these features as individual features. Let us remove this feature from the dataset as a robustness check to ensure our estimates hold as were conducted above.

# %%
# -- dropping the interaction term
feat = feat.drop(columns='Rule of Law X Civil Society')
feat
# Out:
#     civil_society_strength  rule_of_law_strength  Happiness Score  year_2015  \
# 0                    0.604                 0.470            7.187          1
# 1                    0.618                 0.470            6.595          0
# 2                    0.676                 0.474            6.578          0
# 3                    0.678                 0.474            6.488          0
# 4                    0.524                 0.541            6.595          0
# ..                     ...                   ...              ...        ...
# 85                   0.597                 0.394            5.878          1
# 86                   0.597                 0.386            5.743          0
# 87                   0.592                 0.369            5.493          0
# 88                   0.585                 0.418            5.681          0
# 89                   0.596                 0.431            5.743          0
#
# ...

# %%
feat_tr, feat_te, targ_tr, targ_te = train_test_split(feat, targ, test_size=0.2, random_state=63)

# -- fit a decision tree classifier on the TRAINING data
dtc_mod_2 = DecisionTreeRegressor(random_state=63, max_leaf_nodes=9)
dtc_mod_2.fit(feat_tr, targ_tr)

# -- assess the accuracy on the TRAINING data
pred_tr_2 = dtc_mod_2.predict(feat_tr)
mae_tr_2 = mean_absolute_error(targ_tr, pred_tr_2)
print("On Average: Our predictions for our training data were roughly = {0:.5f} units off".format(mae_tr_2))

# -- assess the accuracy on the TESTING data
pred_te_2 = dtc_mod_2.predict(feat_te)
mae_te_2 = mean_absolute_error(targ_te, pred_te_2)
print("On Average: Our predictions for our testing data were roughly {0:.5f} units off".format(mae_te_2))
# Out:
# On Average: Our predictions for our training data were roughly = 0.02703 units off
# On Average: Our predictions for our testing data were roughly 0.02015 units off

# %% [markdown]
# In looking at our training and testing mean absolute errors -- they appear pretty similar to our prior results which suggests that our prior decision tree regression results employing the base and constrained model both held with respect to this newly constrained model predicted here where we dropped the interaction term Rule of law Strength X Civil society strength. But let's examine the R^2 as well below:

# %% [markdown]
# **R^2**

# %%
# Calculating R^2
print('Our model has explained roughly 98% of the variation in "liberal democracy" w/ an R^2 value of {0:.4f}'.format(r2_score(targ_te, pred_te_2)))
# Out:
# Our model has explained roughly 98% of the variation in "liberal democracy" w/ an R^2 value of 0.9833

# %% [markdown]
# Our R^2 value does appear to hold -- as well as our model has once again explained around 98% of the variation in liberal democracy values even when we dropped the interaction term Rule of Law Strength X Civil Society Strength further providing evidence that our main constrained model was a good fit.

# %% [markdown]
# **Feature Importance Bar Chart robustness check 2 column Rule of law X Civ Soc Strength Dropped**

# %%
# -- set mpl stylesheet
plt.style.use("bmh")
# -- plot the top 5 "feature importances" (BUT, BE CAREFUL ABOUT INTERPRETATION!)

# -- create importances DataFrame
imp = pd.DataFrame()
imp['feature'] = feat.columns
imp['importances'] = dtc_mod_2.feature_importances_

# -- select the top 5
top5 = imp.sort_values('importances', ascending=False)[:5]

# -- make the plot
xticks = ['Rule of Law Strength', 'Civil Society Strength', 'Happiness Score', 'Year 2015', 'Year 2016']

fig, ax = plt.subplots(figsize=(8, 3))
top5.plot('feature', 'importances', kind='bar', xlabel='', ylabel='feature importance', legend=False, ax=ax)
ax.set_xticklabels(xticks, fontsize=12)
ax.set_ylabel('Feature Importance', fontsize=12)
fig.show()

# %% [markdown]
# **Figure 4** presents a features importance bar chart of our constrained model that served as a robustness chek with the variable Rule of Law Strength X Civil Society Strength dropped from the features dataframe. We see that once again, rule of law strength is the feature that by far carries the most weight for explaining liberal democracy. In Second place is the feature civil society strength which comes no where close. It is clear that rule of law strength matters for liberal democracy.

# %% [markdown]
# ### **g. Robustness Check 3 -- Shuffling the Values of our Target Variable**

# %%
import random
np.random.seed(1234)

# creating the randomized target variable between 0 and 1 to approximate the values of liberal demoracy variables actual true range
targ_randomized = np.random.rand(90)
targ_randomized = pd.Series(targ_randomized)
targ_randomized
# Out:
# 0     0.191519
# 1     0.622109
# 2     0.437728
# 3     0.785359
# 4     0.779976
#         ...
# 85    0.149834
# 86    0.746063
# 87    0.831007
# 88    0.633726
# 89    0.438310
# Length: 90, dtype: float64

# %%
feat_tr, feat_te, targ_tr_randomized, targ_te_randomized = train_test_split(feat, targ_randomized, test_size=0.2, random_state=63)

# -- fit a decision tree classifier on the TRAINING data
dtc_mod_3 = DecisionTreeRegressor(random_state=63, max_leaf_nodes=9)
dtc_mod_3.fit(feat_tr, targ_tr_randomized)

# -- assess the accuracy on the TRAINING data
pred_tr_3 = dtc_mod_3.predict(feat_tr)
mae_tr_3 = mean_absolute_error(targ_tr_randomized, pred_tr_3)
print("On Average: Our predictions for our training data were roughly = {0:.5f} units off".format(mae_tr_3))

# -- assess the accuracy on the TESTING data
pred_te_3 = dtc_mod_3.predict(feat_te)
mae_te_3 = mean_absolute_error(targ_te_randomized, pred_te_3)
print("On Average: Our predictions for our testing data were roughly {0:.5f} units off".format(mae_te_3))
# Out:
# On Average: Our predictions for our training data were roughly = 0.16034 units off
# On Average: Our predictions for our testing data were roughly 0.26034 units off

# %% [markdown]
# We see here that when examining our testing and training accuracies for when we threw in a completely randomized target variable along with the features -- that our model has performed significantly worse off. Our mean absolute errors for boh our training and testing data were significantly higher than before when we predicted liberal democray (the target) with its actual values and not randomized values. This further provides us evidence that our more constrained model that we optimzed above in the prior section is a robust model and the metrics in terms of R^2 and associated MAE values hold and are robust/valid. Let us further examine the R^2 below to see the differeces between this robustness check model that randomized our target variable and our prior estimates.

# %%
# Calculating R^2
print('R^2 value of {0:.4f}'.format(r2_score(targ_te_randomized, pred_te_3)))
# Out:
# R^2 value of -0.2790

# %% [markdown]
# Overall, we see that our R^2 for this robustness check model is actually negative when typically R^2 values should be betweeon 0 and 1. This negative R^2 value tells us that our model performed very poor at predicting liberal democracy (our target) with our given features. Meanwhile, our prior R^2 values that we found above in our base and constrained models all had R^2 values around 98% suggesting a significant amount of the variation in liberal democracy values was explained by our features. The fact that this R^2 value performs so poorly here further gives us evidence that our base and constrained models performed above are valid, robust, and their estimates hold.

# %% [markdown]
# **Now lets plot the features importance for this robustness check randomized target model**

# %%
# -- set mpl stylesheet
plt.style.use("bmh")
# -- plot the top 5 "feature importances" (BUT, BE CAREFUL ABOUT INTERPRETATION!)

# -- create importances DataFrame
imp = pd.DataFrame()
imp['feature'] = feat.columns
imp['importances'] = dtc_mod_3.feature_importances_

# -- select the top 5
top5 = imp.sort_values('importances', ascending=False)[:5]

# -- make the plot
xticks = ['Rule of Law Strength', 'Civil Society Strength', 'Happiness Score', 'Year 2015', 'Year 2016']

fig, ax = plt.subplots(figsize=(8, 3))
top5.plot('feature', 'importances', kind='bar', xlabel='', ylabel='feature importance', legend=False, ax=ax)
ax.set_xticklabels(xticks, fontsize=12)
ax.set_ylabel('Feature Importance', fontsize=12)
fig.show()

# %% [markdown]
# **Figure 5** plots a feature importance bar chart with our robustness check model where we ranomized the values in our target. Overall, we see here that this model has given more weight to both the rule of law strength feature and civil society strength feature alogn with happiness feature which directly contrasts our prior base and consrtained models that all showed that the feature rule of law strength was at its heart, the most strong and fundamental predictor of liberal democracy values. Therefore, the fact that this robustness check model peformed so poorly further gives us evidence that our constrained model as estimated in the prior sections was our best and most optimal model as no other model had given an indication that civil society strength was a feature that carried alot of importance for liberal democracy values.

# %% [markdown]
# ### **h. Problem Solution Decision Tree Regression**

# %% [markdown]
# Overall, what our decision tree regression analyses as conducted above has shown is that by far -- the strength of rule of law for a given Latin American country is the most significant predictor of liberal democracy for countries in Latin America. Therefore, for policymakers and politicians alike on the ground in the region, a major emphasis should be placed on strengthening the rule of law above anything else in order to not only preserve, but also to srengthen liberal democracy in the region as well.

# %% [markdown]
# # **8. Overall Problem Solution: Latin American Region**

# %% [markdown]
# * For our KMeans clustering analysis -- in conclusion, it poses a problem that both Cuba & Venezuela remain key outliers in a negative sense for their levels of democracy, civil society strength, and rule of law strength respectively -- the main features & target (liberal democracy) in our analysis. With this finding, International organizations and democratic nations around the world should continue to engage in dialogue with both of these countries while proposing measures that would aid them and their populace to democratize and overthrow the current authoritarian regimes present in both of these countries. It will also be important for policymakers moving forward with respect to liberal democracy feature especially to understand why it was in Figure 2 panel 1 in the Kmeans cluster section of this analysis, that we had 1 cluster (cluster 0 in blue & its members) that stopped increasing in its levels of liberal democracy around the year 2000 in contrast to cluster 2 in purple and its members which continue the trend of increasing in its liberal democracy scores. Policymakers and academics alike should analyze in greater depth the difference amongst members that belong to these respective clusters between these two clusters to undestand why increasing liberal democracy scores came to a halt in cluster 0 but continued to increase in cluster 2 after the year 2000. Doing so will be beneficial for understanding why democratic progress halted in some countries of the region but continued in others. To do so in this study, however, is beyond the scope of this analysis.
#
#
# * With regards to our Logistic Regression analysis -- from our various panel plots as shown in figure 4 in the logistic regression section of this notebook -- it is clear that the rule of law strength matters a great deal for being predicted a democracy (outcome = 1) relative to non-democracy (outcome = 0) as does Happiness. For the variable civil society strength however, the magnitude of the effect is much less pronounced relative to rule of law strength and happiness scores when it comes to predicting an outcome of 1 (democracy) relative to 0 (non-democracy). Nonetheless, the effect is still there -- where greater levels of civil society strength do show an increased probability of being a given country in Latin America being a democracy relative to non-democracy. With that said, however, the conclusion by and large from our logistic regression analyses is that the most important feature for being a liberal democracy is the rule of law strength where the stronger the rule of law -- the greater the probability that a country will be a democracy relative to non-democracy.
#
# * For our decision tree regression analysis -- what our decision tree regression analyses as conducted above in the decision tree regression section has shown is that by far -- the strength of rule of law for a given Latin American country is the most significant predictor of liberal democracy for countries in Latin America . Therefore, for policymakers and politicians alike on the ground in the region, a major emphasis should be placed on strengthening the rule of law above anything else in order to not only preserve, but also to srengthen liberal democracy in the region as well.
#
# **In conclusion, brining our findings together for the Latin American region, it is imperative to continue to engage in dialogue with the main autocratic countries in the region (Cuba & Venezuela) in order to continue to push these countries to liberalize their regimes in all aspects. Moreover, the importance of a strong rule of law cannot be discounted for countries in Latin America that seek to improve their levels of liberal democracy.**
